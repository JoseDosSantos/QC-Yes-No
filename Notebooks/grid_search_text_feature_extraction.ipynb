# %%
# %matplotlib inline

# %% [markdown]
# # Sample pipeline for text feature extraction and evaluation
#
#
# The dataset used in this example is the 20 newsgroups dataset which will be
# automatically downloaded and then cached and reused for the document
# classification example.
#
# You can adjust the number of categories by giving their names to the dataset
# loader or setting them to None to get the 20 of them.
#
# Here is a sample output of a run on a quad-core machine::
#
#   Loading 20 newsgroups dataset for categories:
#   ['alt.atheism', 'talk.religion.misc']
#   1427 documents
#   2 categories
#
#   Performing grid search...
#   pipeline: ['vect', 'tfidf', 'clf']
#   parameters:
#   {'clf__alpha': (1.0000000000000001e-05, 9.9999999999999995e-07),
#    'clf__n_iter': (10, 50, 80),
#    'clf__penalty': ('l2', 'elasticnet'),
#    'tfidf__use_idf': (True, False),
#    'vect__max_n': (1, 2),
#    'vect__max_df': (0.5, 0.75, 1.0),
#    'vect__max_features': (None, 5000, 10000, 50000)}
#   done in 1737.030s
#
#   Best score: 0.940
#   Best parameters set:
#       clf__alpha: 9.9999999999999995e-07
#       clf__n_iter: 50
#       clf__penalty: 'elasticnet'
#       tfidf__use_idf: True
#       vect__max_n: 2
#       vect__max_df: 0.75
#       vect__max_features: 50000

# %%
from __future__ import print_function

from pprint import pprint
from time import time
import logging

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
# Display progress logs on stdout
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')

# %%
# #############################################################################
# Load some categories from the training set
categories = [
    'alt.atheism',
    'talk.religion.misc',
]
# Uncomment the following to do the analysis on all the categories
#categories = None

# %%
print("Loading 20 newsgroups dataset for categories:")
print(categories)
# Out:
# Loading 20 newsgroups dataset for categories:
# ['alt.atheism', 'talk.religion.misc']

# %%
data = fetch_20newsgroups(subset='train', categories=categories)
print("%d documents" % len(data.filenames))
print("%d categories" % len(data.target_names))
print()
# Out:
# Downloading 20news dataset. This may take a few minutes.
# 2018-09-23 03:59:31,638 INFO Downloading 20news dataset. This may take a few minutes.
# Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)
# 2018-09-23 03:59:31,639 INFO Downloading dataset from https://ndownloader.figshare.com/files/5975967 (14 MB)
# 857 documents
# 2 categories

# %%
len(data.target)
# Out:
# 857

# %%
import re
def clean(string):
    #return string
    clean_string = re.sub(r'\d+', 'number', string)
    clean_string = re.sub(r'Ä', 'Ae', clean_string)
    clean_string = re.sub(r'ä', 'ae', clean_string)
    clean_string = re.sub(r'Ö', 'Oe', clean_string)
    clean_string = re.sub(r'ö', 'oe', clean_string)
    clean_string = re.sub(r'Ü', 'Ue', clean_string)
    clean_string = re.sub(r'ü', 'ue', clean_string)
    clean_string = re.sub(r'ß', 'ss', clean_string)
    clean_string = re.sub(r'°', 'Grad', clean_string)
    clean_string = re.sub(r'[Zz][Bb]', 'zum Beispiel', clean_string)
    clean_string = re.sub(r'[Dd][Hh]', 'das heißt', clean_string)
    clean_string = re.sub(r'[Bb][Ss][Pp][Ww]', 'beispielsweise', clean_string)
    clean_string = re.sub(r'[Hh]allo', '', clean_string)
    clean_string = re.sub(r'[Hh]i', '', clean_string)
    clean_string = re.sub(r'[Hh]ey', '', clean_string)
    clean_string = re.sub(r'[Gg]uten\s[Mm]orgen', '', clean_string)
    clean_string = re.sub(r'[Gg]uten\s[Aa]bend', '', clean_string)
    
    clean_string = re.sub(r'(\([^)]*\))', ' ', clean_string)
    clean_string = re.sub(r'"', '', clean_string)
    clean_string = re.sub(r'\+', '', clean_string)
    clean_string = re.sub(r'-', '', clean_string)
    clean_string = re.sub(r',', '', clean_string)

    clean_string = re.sub(r'\'', '', clean_string)
    clean_string = re.sub(r'\.', '', clean_string)
    clean_string = re.sub(r'\s{2,}', ' ', clean_string)
    clean_string = re.sub(r'\s(?=\?)', ' ', clean_string)
    clean_string = re.sub(r'\?*(?=(?:\?))', '', clean_string)
    clean_string = clean_string.strip()
    #bitte, danke, und, eigentlich, überhaupt, git, wirklich
    return clean_string#.lower()

import Classification.config as cfg
import csv
data_set = []
for file in cfg.ALL_FILES:
    reader = csv.reader(open(file, 'r'), delimiter=';')
    for line in reader:
        try:
            data_set.append([clean(line[0]).lower(), line[1]])
        except Exception as e:
            print()

# %%
data_frame = pd.DataFrame(data_set)
# Out:
# ['ist der ttstift lauter als die number generation?',
#  'kann der tiptoi create auch hoerbuecher abspielen?',
#  'ist da trotzdem auch die player funktion enthalten?',
#  'geht die reichweite von der basis oder von der fernbedienung aus?',
#  'wie lang piept das geraet?',
#  'hat jemand erfahrung wie lange die batterien halten sowohl im sender als auch im empfaenger?',
#  'wie dick ist der sender?',
#  'wie sind denn die genauen masse des piepers in cm?',
#  'sind die karten auf deutsch?',
#  'kann mann die festplatte auch in einer playstation number pro einbauen?',
#  'was passiert wenn die leer ist?',
#  'kann ich die da formatieren?',
#  'wie lange sind die batterien haltbar?',
#  'hat jemand welche?',
#  'ist die firma flower bud serioes?',
#  'wie gross ist der durchmesser fuer die bepflanzung?',
#  'wie kann das sein das ich post vom zoll kriege und weit fahren muss um ihn abzuholen?',
#  'sind airpods dabei?',
#  'gibt es garantie dazu?',
#  'kann man das iphone number auch in oesterreich nutzen?',
#  'ist der wsky getorft ?',
#  'kann man diesen wsky mit cola mischen?',
#  'warum sind wskys vom versand nach oesterreich ausgeschlossen?',
#  'wie sieht das denn mit der garantie aus?',
#  'wie halten die airpods in kleinen ohren?',
#  'kann man den stecker auch mit dem ikea tradfri gateway koppeln?',
#  'wie verhaelt sich die steckdose nach einem stromausfall?',
#  'mit welcher leistung kann die steckdose belastet werden?',
#  'sind die farben auf einfarbig einstellbar?',
#  'wie viele farben und farbenkombinationen hat sie?',
#  'sind die tasten leise oder klicken sie beim druecken?',
#  'ist die tastatur mechanisch?',
#  'kann man auch nur eine farbe benutzen?',
#  'kann man die fledermausfluegel runter machen?',
#  'kann man einen weiteren kopfhoerer verbinden?',
#  'kann mir jemand sagen wie lang das kabel ist?',
#  'wie kann man an den kopfhoerern die lautstaerke anpassen?',
#  'was ist bei der neuauflage anders als vorher?',
#  'gibt es in dem spiel auch eine englischspracge anleitung?',
#  'welche art batterien brauche ich dafuer?',
#  'ist dies jetzt extra ein vorschulspiel?',
#  'zu\xa0welcher\xa0tageszeit\xa0ist\xa0die\xa0am\xa0besten\xa0geeignete\xa0messung?',
#  'ist das bequem zu tragen?',
#  'wieviele messungen kann dieses geraet speichern?',
#  'gibt es einen untersced zwischen der verwendung des linken arms und des rechten arms?',
#  'hat der rasenmaeher ein elektrostarter?',
#  'kann man den rasenmaeher platzsparend hochkant stellen oder geht das beim benziner nicht?',
#  'was fuer benzin super oder enumber?',
#  'hat der rasenmaeher einen heckauswurf oder seitenauswurf?',
#  'sind das dann insgesamt number versionen?',
#  'welches angebot ist das richtige?',
#  'ist die brille polarisiert?',
#  'welche schutzstufe hat diese brille?',
#  'ist diese wayfarer sonnenbrille sehr leicht?',
#  'ist der tempel dieser brille echtes holz?',
#  'wie ist das innenmass von der breite?',
#  'wie ist die gps genauigkeit?',
#  'was ist die maximal messbare geschwindigkeit?',
#  'wie kann ich die datenfelder mit der software veraendern am sigma geraet?',
#  'kann der die gefahrenen hoehenmeter auch kummulieren und diese in einem individuell zusammengestellten profil anzeigen?',
#  'passt der schlauch an der beko wmb number pteu waschmascne ?',
#  'ist der schlauch geeignet fuer eine siemens wmnumberwnumber waschmascne?',
#  'passt der schlauch auch an gescrrspuelmascne privileg?',
#  'ist es normal dass das sichtfenster halb rot gefuellt ist?',
#  'wie lange soll ich den beutel erneuern?',
#  'kann man audible auf das tablet runterladen?',
#  'ist der zugriff auf google play store moeglich?',
#  'ist bei dem set jeweils number account kostenlos dabei?',
#  'wieviele steine sind es?',
#  'sind die wuerfel wirklich geschmacksneutral?',
#  'ist der speckstein gefaehrlich?',
#  'wie lange kuehlen die steine in etwa?',
#  'gibt es eine begrenzung des systems?',
#  'kann das geraet ueber usb geladen werden?',
#  'kann die dockingstation vom pro number verwendet werden?',
#  'kann ein auxkabel ohne probleme angesteckt werden?',
#  'gibt es davon verscedene farben?',
#  'warum bekomme ich den code fuer die beta nicht ?',
#  'ist das spiel auf deutsch?',
#  'won wird der beta code versendet?',
#  'ist das geraet linux kompatibel?',
#  'hat das geraet eine airprint funktion?',
#  'kann das geraet farbig scannen?',
#  'kommt mit dem geraet die number jahre garantie?',
#  'schaltet das geraet automatisch ein wenn ein druckauftrag per wlan gesendet wird?',
#  'wie wird der universalhalter numbermm benutzt?',
#  'passt diese bit box in die lbox?',
#  'kann man die bits auch mit ein drehschlagschrauber nutzen?',
#  'wie viel gramm wasser passen pro eiswuerfel in die form?',
#  'wie gross sind die eiswuerfel eigentlich?',
#  'sind die deckel dicht?',
#  'was ist der untersced zum vorgaenger?',
#  'unterstuetzt der drucker auch das beidseitige scannen in einem schritt also ohne wenden?',
#  'wie lang ist das stromkabel?',
#  'saugt er wasser zb aus einer regentonne an?',
#  'ist er eine rotierende dreckfraese dabei?',
#  'an wen kann ich mich wenden wenn die lieferung nicht komplett ist?',
#  'kann man das auch fuer torwarttraining nutzen?',
#  'sind dichtungsringe dabei?',
#  'ist der duschkopf auf dem schlauch drehbar gelagert?',
#  'funktioniert netflix mit dem geraet?',
#  'hat das geraet aussen mechanische lautstaerketasten?',
#  'kann man sich im karrieremodus wieder jeden rennstall aussuchen oder muss man sich hocharbeiten?',
#  'kann man den wasserfall abschalten bzw auf englischen kommentar wechseln?',
#  'gibts einen splitscreen modus oder muss man das alleine spielen?',
#  'kann ich die auch benutzen wenn ich selbst badekugeln machen moechte?',
#  'ist die lebensmittelfarbe fluessig?',
#  'was bedeutet tadago edition?',
#  'ist dieses leuchtmittel fuer eine lavalampe geeignet?',
#  'kann mir jemand sagen wo dieser tamper hergestellt wurde?',
#  'ist die unterseite eben oder konvex?',
#  'kann man den helm vom polizisten abnehmen ?',
#  'wie lange haelt der akku wen das navi aufgeladen ist?',
#  'sind die karten und updates fuer anderer europaeische laender auch kostenlos?',
#  'kann mir jemand sagen in welchen sprachen die spielanleitung ist?',
#  'ist das spiel auch zu zweit lustig?',
#  'handelt es sich erbei um das small breed futter?',
#  'passt dieser filter fuer die neue eletta von de long?',
#  'wie viele filter sind in der lieferung?',
#  'wie giftig ist der griff?',
#  'ist das so einer wo man nur am griff drehen muss?',
#  'wie ist es mit der schadstofffreiheit?',
#  'wie lang ist das kabel?',
#  'ist die farbe matt oder glaenzend schwarz ?',
#  'wie lang ist das kabel?',
#  'reicht das aus um number solche viereckregner komplett auszulasten?',
#  'wie gut haelt die dose im boden?',
#  'ist bei dem deutschen spiel auch eine anleitung auf englisch dabei?',
#  'welches abfuelldatum steht auf den flaschen?',
#  'mit welchem versanddienstleister wird das oel versandt?',
#  'verharzt das oel wenn man die saege laenger nicht benutzt?',
#  'ist die maske auch fuer reife trockene haut geeignet?',
#  'wieviel % hyaloronsaeure sind enthalten?',
#  'hat schon jemand langzeiterfahrung damit gemacht?',
#  'kann ich wasserflussgeschwindigkeit waehlen?',
#  'aus welchem material besteht der duschkopf?',
#  'welchen durchmesser und welches gewicht hat der duschkopf?',
#  'wie lang ist der schlauch der mitgeliefert wird?',
#  'ist in dem bettlaken elasthan enthalten?',
#  'bezahle ich zweimal versand wenn ich zwei laken bestelle?',
#  'wie lange haelt das produkt bei taeglicher anwendung?',
#  'wieviel oel ist in der flasche?',
#  'kann man dieses oel waehrend der schwangerschaft vorbeugend gegen dehnungsstreifen anwenden?',
#  'wie sieht das eigentlich rein rechtlich aus?',
#  'besteht die gefahr des eintritts des gifts in wohnraeume?',
#  'ist die petflasche fuer die spuelmascne geeignet?',
#  'ist der ersatzzylinder bereits gefuellt?',
#  'sind die conumber zylinder fuer alle sodastreamgeraete die gleichen?',
#  'hat die flasche einen bajonetteverschluss?',
#  'wo kann man ersatzfilter kaufen bzw wann muessen sie getauscht werden?',
#  'ist das normal?',
#  'ist eine pumpe enthalten?',
#  'wie kann ich etwas luft aus dem kissen ablassen?',
#  'was fuer eine verbindung haben die rollen?',
#  'sind bei diesem sessel auch die number polster enthalten?',
#  'wie wird diese klingel befestigt?',
#  'wieso gibt es er mehrfache rezensionen von der gleichen person?',
#  'hat diese klingel eine rueckholfeder?',
#  'gibt es eine maximale belastbarkeit?',
#  'wie lang sind die schrauben zur befestigung?',
#  'gibt es eine absenkungautomatik?',
#  'sind die bettlaken flauscg oder glatt vom stoff?',
#  'welche leintuchgroesse brauche ich fuer eine numberxnumber grosse und numbercm hohe matratze?',
#  'worauf muss ich achten?',
#  'wie kann man anrufe annehmen?',
#  'ist die uhr jetzt nun wassertauglich oder nicht?',
#  'wie lang ist der drache?',
#  'wie ist das packmass fuer das numberxnumbercm und das numberxnumbercm handtuch ?',
#  'kann man es nach dem baden im meer benutzen?',
#  'gibt es einen ersatzakku fuer den rasentrimmer?',
#  'wie lange ist die ladezeit?',
#  'wuerde er auch brennessel und anderes unkraut schaffen?',
#  'ist bei dem w der dosierloeffel mit dabei?',
#  'ist das produkt lactosefrei?',
#  'wieso hat das w bei numberg nur numbernumberg protein?',
#  'mit welchen fluessigen getraenken ruehrt ihr euer w an?',
#  'wo ist der untersced zwichen der mxnumber und der mxnumber?',
#  'weshalb steht in der beschreibung nach dem oeffnen kuehl lagern?',
#  'warum kann ich mir von amazon kein alkohol nach oesterreich sccken lassen?',
#  'kann man die schuhe wieder zuruecksenden falls sie nicht passen oder ist das schwierig?',
#  'passt die angegebene schuhgroesse?',
#  'ist das ein snumber sicherheitsschuh?',
#  'sind die glaeser blaugruen verspiegelt oder nur gruen verspiegelt?',
#  'ist die sonnenbrille number% verspiegelt und somit blickdicht?',
#  'ist die brille fuer maenner und frauen geeignet?',
#  'ist der handschuh aus baumwolle?',
#  'wann kann man als vorbesteller das spiel downloaden?',
#  'wie viele hdd kann man er einbauen?',
#  'ist es normal dass der laptop auch unter geringer belastung extrem heiss wird und staendig laut lueftet?',
#  'kann man in der first person ansicht spielen?',
#  'ist die schaumeinlage dabei oder muss man die seperat bestellen?',
#  'ist der laser auch fuer aussenbereiche zu gebrauchen?',
#  'sehr geehrter damen und herren was ist das fuer eine messtabelle die dem geraet beigefuegt ist?',
#  'kann das armband sowie die batterie der vivosmart hr bei bedarf getauscht werden?',
#  'kann ich auf dem display in einem feld die aktuelle hoehe erkennen?',
#  'hat er einen boden?',
#  'ist er rueckenunterstuetzend?',
#  'kann man ihn waschen?',
#  'sind die applikationen aus echtem leder?',
#  'kann ich filme die ich auf dem tabet habe auch auf einen fernseher ansehen?',
#  'hat man auch zugriff auf den google playstore oder muss man sich auf den amazon playstore beschraenken?',
#  'wie viele werktage dauert der versand?',
#  'welche groesse sollte ich bestellen ?',
#  'rutscht sie runter beim laufen?',
#  'wann ist die hose ungefaehr da?',
#  'kann ich dieses material auch umlackieren und wenn ja mit welchem lack ?',
#  'haelt der deckel dies dauerhaft aus oder gibt es verformungen?',
#  'ist das touchdisplay mit einem glas oder durch kunststoff geschuetzt?',
#  'koennte man auch number kisten aufeinander schrauben?',
#  'wie hoch ist der zoo?',
#  'wie lange hat deine band gedauert?',
#  'schwitzt deine haut unter dem band?',
#  'enthaelt das armband nickel?',
#  'wie saeuberst du das band?',
#  'ist das schwarze armband auch dabei?',
#  'was ist alles im lieferumfang enthalten?',
#  'wenn ich den artikel heute vorbestelle wann muss es bezahlen?',
#  'was ist der untersced zwischen der charge number und der charge number special edition?',
#  'warum wird dieser artikel nicht mehr nach oesterreich vescckt?',
#  'sind die riemen an den schultern verstellbar?',
#  'ist es normal dass der ntergrund des logos eher gelblich anstatt ganz weiss ist?',
#  'hat es in drinne noch ein fach?',
#  'ist der rucksack gut fuer die schule?',
#  'wie lang ist das kabel?',
#  'welche stromstaerke liefert das netzteil denn bei den einzelnen spannungen genau?',
#  'ist england dabei?',
#  'was bedeudet dab?',
#  'ist das display entspiegelt?',
#  'wodurch unterscheiden sich die geraete mit verkehrsinformationen bzw ohne verkehrsinformation?',
#  'funktioniert das streamen von musik von einer festplatte mit mpnumberdateien die am router haengt?',
#  'kann man damit auch die breikostbehaelter von avent erwaermen?',
#  'eignet sich der flaeschchenwaermer auch fuer glasflaschen?',
#  'reicht diese karte fuer die gear number oder muss es die pro plus sein?',
#  'hat das notebook numbergb speicher oder numbert?',
#  'gibt es eine garantie auf den laptop?',
#  'wie installiere ich windows number von einer cd?',
#  'ist neben der im geraet verbauten number gigabyte hdd eine sdd einbaubar?',
#  'was ist der untersced zwischen delong ecam number b und sb?',
#  'wieviel gramm kaffee wird pro tasse gemahlen?',
#  'warum kann man bei ihnen nicht number drueckerplatten auswaehlen?',
#  'kann der echo show als tablett genutzt werden?',
#  'ist youtube auch nutzum beispielar?',
#  'ist die lieferung zu einem wunschtermin moeglich?',
#  'lieferung nach oesterreich moeglich?',
#  'was stimmt?',
#  'welche schlauchgroesse passt in dieses klicksystem?',
#  'wie hoch ist die dose?',
#  'ist das spiel gut zu zweit spielbar oder macht es wie so viele erst ab drei spielern richtig spass?',
#  'wann wird das spiel vorraussichtlich wieder verfuegbar sein?',
#  'kann man das papier automatisch beidseitig bedrucken lassen?',
#  'hat der drucker nun ein geschlossenes papierfach oder nicht und wenn ja wo ist es?',
#  'wieviel blaetter passen in das papierfach?',
#  'welchen trinkaufsatz kann ich fuer den becher nutzen?',
#  'hergestellt in deutschland?',
#  'kann man die schalen und das besteck auch sterilisieren?',
#  'kann man die haube in der waschmascne reinigen?',
#  'ist diese huelle wasserdicht ?',
#  'hat der rucksack einen brustgurt?',
#  'haben in den seitentaschen je eine numbernumberl flasche platz?',
#  'passt seitlich in den faechern eine trinkflasche nein?',
#  'wie lang ist das kabel?',
#  'wie hoch ist diese steckdose bitte belastbar?',
#  'ist die steckdose auf der rueckseite verschraubt oder vernietet?',
#  'wird von das heißtl eine altersueberpruefung gemacht?',
#  'muss man sich bei annahme des paketes als uenumber ausweisen?',
#  'laesst sich das display nachts auch komplett abstellen und nicht nur dimmen?',
#  'kann man youtube videos schauen?',
#  'kann es auch netflix?',
#  'kann man das android auf die neueste version updaten oder ist man an android numberx gebunden?',
#  'wie sieht er der garantiesupport aus?',
#  'koennen apps auf der speicherkarte installiert werden?',
#  'wie werden sie eingenommen?',
#  'sind druckerfarben im lieferumfang enthalten?',
#  'ist im lieferumfang ein erster satz patronen enthalten?',
#  'stimmt es dass die druckersoft nur mit originaltinten also nicht mit kompatibler tinte funktioniert?',
#  'ist diese festplatte auch fuer mac kompatibel und eignet sie sich auch fuer time macne?',
#  'zieht die platte den strom vom usbport oder wird ein externes netzteil angeschlossen?',
#  'wie viel umdrehung hat die festplatte?',
#  'wie lang ist das beiliegende usb kabel?',
#  'hat die mascne warmwasseranschluss?',
#  'hat die mascne einen beladungssensor?',
#  'kann ich das fluessigwaschmittel ganz normal einfuellen?',
#  'passen in die mikrowelle auch teller mit number cm durchmesser?',
#  'sind luftschlitze an der linken seite oder nur oben?',
#  'ist diese serie auch fuer herren gedacht?',
#  'ist diese serie nur fuer damen geeignet?',
#  'wie viele haekchen hat der verschluss?',
#  'lassen sich diese led stripes auch ueber die hue bridge steuern?',
#  'kann man die rgb birnen auch in ein hue system einbinden und mittels app dann in hue szenen nutzen?',
#  'lassen sich die schultergurte in der laenge verstellen?',
#  'wie breit ist der gurt?',
#  'welche voroder nachteile hat er gegenueber dem brother mfclnumber?',
#  'kann man damit auch andere formate bedrucken wie anumber anumber ?',
#  'kann ich auch steuererklaerungen fuer zurueckliegende jahre erstellen?',
#  'gibt es die version auch als download?',
#  'helfen die schlupfwespen gegen lebensmittelmotten auch gegen kleidermotten?',
#  'in welchem zeitlichen abstand werden die kaertchen zugescckt?',
#  'was ist eigentlich neu an der neuesten version?',
#  'kann ich diese version auf vorhandene vista number bit drueber installieren ?',
#  'ist das obermaterial durchsichtig oder ist es mehrlagig?',
#  'tut das in der nase weh?',
#  'wie reinigt man den trimmer am besten?',
#  'kann man aufsaetze einzeln kaufen?',
#  'gibt es eine schnittstelle zu datev?',
#  'ist diese software auch fuer die umsatzsteuervoranmeldung geeignet?',
#  'kann ich das programm auch verwenden wenn ich noch ein kleingewerbe habe?',
#  'warum wird ron zacapa nicht nach oesterreich geliefert?',
#  'ist im lieferumfang die schwarze runde verpackung enthalten?',
#  'ist geschenkverpackung dabei?',
#  'wie viele beutel sind beinhaltet?',
#  'warum ist die lieferzeit im moment so lange?',
#  'hat die lampe eine automatische abschaltautomatik oder muss ich sie immer neu einstellen?',
#  'sind number oder number watt besser zum lesen?',
#  'ist die lampe voellig lautlos?',
#  'ist auf dem laptop windows installiert?',
#  'hat dieser laptop windows number?',
#  'welche software ist vorinstalliert?',
#  'kann man einstellen wie viel luftfeuchtigkeit man pro mnumber haben will?',
#  'ist das geraet auch fuer kleinere raeume geeignet?',
#  'kann man den laptop mit einem iphone verbinden und die bilder darauf speichern?',
#  'ist ein ladekabel dabei?',
#  'wie viel mah hat eine batterie?',
#  'was ist der untersced zwischen lrnumber und lrnumber?',
#  'sind die nur als vogelfutter gedacht oder kann ich die auch selber essen?',
#  'sind das jetzt number monate oder insgesamt number monate?',
#  'ist die karte bei lieferung bereits aktiviert?',
#  'sind koffer netzteil und batterien im lieferumfang enthalten?',
#  'welche textilschriftbaender zum einbuegeln koennte man fuer dieses geraet verwenden ?',
#  'in welchen groessen sind die druckbuchstaben variierbar?',
#  'welche abmessungen hat dieser artikel?',
#  'passt da auch ein tetrapak milch rein?',
#  'wie gross ist der kuehlschrank?',
#  'macht der kuehlschrank geraeusche?',
#  'ist ein blauer bosch koffer oder eine noname handwerkerkoffer dabei?',
#  'ist die lboxx in diesem paket dabei?',
#  'wie ist die schnitttiefe bei der gst number ce?',
#  'wie bekommt man den durchsichtigen splitterschutz wieder ab?',
#  'wie ist das gewicht des balls?',
#  'wie viel wiegt der ball groesse number?',
#  'kann man die jeden abend abziehen?',
#  'schauen sie schoen und naturel aus?',
#  'kann man eine wimper noch mal verwenden?',
#  'wie lange halten sie?',
#  'wieviel rollen bekommt man fuer numbernumber?',
#  'warum ploetzlich so teuer?',
#  'um wieviele packungen handelt es sich bei diesem angebot?',
#  'wie wird die ware geliefert?',
#  'ist es moeglich das aktivierungswort zu aendern?',
#  'fuer welches alter sind die flaschen?',
#  'ist die flasche auch fuer kohlensaeurehaltige getraenke geeignet?',
#  'kann man den strohhalm entfernen und die flasche trotzdem benutzen?',
#  'welcher kompressor ist geeignet?',
#  'wenn es so klein ist kriegt man das wieder gescheit aus der ladebuchse?',
#  'drueckt sich der pin wie bei mir schraeg ein?',
#  'stoert das geraet den radioempfang?',
#  'welche batterien kommen in die kamera?',
#  'ist in der kamera schon ein film mit enthalten?',
#  'ist die farbe echt so krass pink oder ist des ein helles rosa?',
#  'welche farbe hat die waage denn?',
#  'wie lange ca halten die batterien?',
#  'kann man in der waage mehrere profile speichern?',
#  'ist die bruecke auch mit der alten eisenbahn kompatibel?',
#  'wie viel datenvolumen hat der laptop?',
#  'koennen mit dem geraet faxe empfangen und versandt werden ohne den pc anzuschalten?',
#  'koennen auch vom handy dokumente gedruckt werden?',
#  'ist die urheberrechtsabgabe fuer oesterreich in diesem preis includiert?',
#  'kann das band beim schwimmen die bahnen zaehlen?',
#  'welche masse hat der koffer in m?',
#  'sind alle drei koffer erweiterbar?',
#  'sind das auch wirklich numbergb?',
#  'ist es hochglanz oder matt?',
#  'wie viele hdml ein und ausgaenge hat das geraet?',
#  'wie ist die qualitaet des deckels?',
#  'muss ich fuer die verwendung von furbo bezahlen?',
#  'funktioniert der furbo auch mit number ghz?',
#  'kann ich auf dieses tablet whatsapp installieren?',
#  'kann man mit dem tablet vernuenftig schreiben wenn ich mir einen sstift dazu holen wuerde?',
#  'kann man damit mandelmus herstellen?',
#  'gibt es eine garantie fuer dieses geraet?',
#  'wie lang ist die uhr genau?',
#  'ist die batterie bereits enthalten?',
#  'helfen die wespen auch bei motten die nochverpuppt sind?',
#  'wie sind die produktabmessungen?',
#  'was passiert wenn die batterie leer ist?',
#  'wie hoch ist der turm im aufgebauten zustand?',
#  'kann ich es mit einer simkarte verwenden?',
#  'ist dieses tablet mit einer speicherkarte erweiterbar?',
#  'laesst sich android auf version numbernumber aktualisieren?',
#  'ueberlese ich die ganze zeit bluetooth oder gibt es das nicht?',
#  'sind die groessenangaben realistisch?',
#  'wird es eine batterie enthalten?',
#  'ist das geraet auch fuer saeuglinge von number monaten geeignet?',
#  'wie kann ich das thermometer auf cgrad umstellen?',
#  'ist der becher spuelmascnengeeignet?',
#  'wie hoch ist der becher ohne deckel?',
#  'aus welchem material besteht der deckel?',
#  'kann man den becher auch mit persoenlicher gravur bestellen?',
#  'welche hoehe des werkstueckes hat platz?',
#  'passt der thermoscan number auch mit der mitgelieferten plastikhalterung/ schale nein?',
#  'ist dieser artikel die ueberarbeitete version die auch number^numbermm huelsen pressen kann?',
#  'welche maximale huelsenlaenge kann ich damit crimpen?',
#  'welche maximale huelsenlaenge kann ich damit crimpen?',
#  'eignet sich diese kamera fuer konzerte?',
#  'welche sdxccps lassen sich verwenden?',
#  'hat die kamera gps?',
#  'sind diese saiten nickelfrei?',
#  'gehen diese saiten auch fuer eine dreiviertelgrosse kindergitarre?',
#  'kann man die saiten auch zusammenkleben?',
#  'kommt die ware aus dem ausland?',
#  'wie gross ist der durchmesser oben?',
#  'wird die schultuete immer noch platt gedrueckt also geknickt und unbrauchbar versendet?',
#  'also kann ich die auch in einen anderen schraubenzieher oder gar in einen akkuschrauber packen?',
#  'wieso lese ich positive bewertungen von werkzeugtaschen?',
#  'von wo wird das geraet verscckt also aus welchem land?',
#  'eignen sich die dinger auch fuer den pcbau ?',
#  'wie waehle ich er das kabel fuer mein iphone number aus?',
#  'sind im zweierpack beide kabel einzeln oder gemeinsam verpackt?',
#  'welche groesse hat der lightning anschluss?',
#  'ist er auch mit iphone und ipad kompatibel?',
#  'welche kompatiblen fremdpatronen nimmt der drucker ohne probleme an?',
#  'sind diese dann auch richtig durch ertzt?',
#  'was ist denn der untersced zum backofen mit umluft?',
#  'wieviele broetchen kann man aufbacken?',
#  'ist das normal dass das geraet waehrend des betriebs total laut ist und klappert?',
#  'ist das normal dass das geraet so stark raucht?',
#  'bleiben die einstellungen erhalten wenn man die birne ueber den stromschalter ausschaltet?',
#  'ist es wirklich eine gluehbrine mit led?',
#  'wie hoch/lang ist die lampe?',
#  'ist es moeglich das licht zu steuern ohne daheim zu sein?',
#  'was ist denn der untersced zwischen anumber anumberanumber?',
#  'kann mir jemand helfen?',
#  'sind die dosen fuer fluessigkeiten geeignet?',
#  'kann ich die dosen auch in den backofen stellen?',
#  'tragen alle dosen das bpa frei zeichen ?',
#  'wieviel milliliter passen da ueberall nein?',
#  'wird es moeglich sein das spiel auch mit englischer sprachausgabe zu spielen?',
#  'ist das eine cd oder eine art cp wie bei numberds ?',
#  'wielange dauert es bis ich den downloadcode erhalte?',
#  'gibt es eine bedienungsanleitung in deutscher sprache?',
#  'wie kurz kann man das armband einstellen?',
#  'kann man auch ersatzteile fuer dieses modell bestellen?',
#  'ist die uhr fuer kaeufer mit chromnickelallergie geeignet?',
#  'wird die uhr mit batterie geliefert bzw ist sie sofort funktionsfaeg?',
#  'ist auf der uhr eine garantie?',
#  'wo liegt der untersced zwischen den beiden versionen?',
#  'koennte dies fuer ihn noch zu schwer sein?',
#  'macht es auch genug spass wenn man nur zu zweit spielt?',
#  'welche batterien kommen in die kamera?',
#  'ist in der kamera schon ein film mit enthalten?',
#  'warum ist das schloss fuer numbernumber angeboten und im warenkorb dann fuer numbernumber?',
#  'welche sicherheitsstufe?',
#  'eignet sich das schloss auch fuer ein puky laufrad?',
#  'kann ich das spiel auch auf der xbox one spielen?',
#  'kommt das spiel als code oder cd?',
#  'warum kann ich er die champions edition nicht vorbestellen?',
#  'ist der versand bis in die wohnung?',
#  'kann man auch nur schleudern einstellen?',
#  'ist die waschmascene dank der rollen ohne weiteres fahrbar?',
#  'liefrung bis in die wohnung oder bis borsteinkante?',
#  'nehmen sie altgeraete mit?',
#  'kann ich das mittel in der naehe eines koi teiches anwenden?',
#  'kann man das mittel in unmittelbarer naehe von scldkroeten benutzen?',
#  'welche art von simkarte braucht das snumber?',
#  'ist dies ein dual sim geraet?',
#  'ist dieses telefon ausserhalb deutschlands verwendbar dh kompatibel mit einer irischen simkarte?',
#  'kann man das auch auf die haut tragen wenn man gar keine augenbrauen hat?',
#  'welche farbe sollte man waehlen bei rotem haar?',
#  'nach wie vielen tagen wird es dann rausgehen?',
#  'gibt es die anleitung auch auf englisch?',
#  'funktioniert dann das mikrophone?',
#  'funktioniert der adapter auch mit einer psnumber?',
#  'wie sind die aufnahmen im dunkeln/ schlechte beleuchtung?',
#  'ist dieses produkt antischock?',
#  'kann mir jemand weiterhelfen?',
#  'kann man den tragegurt der tasche wirklich nur in zwei laengen einstellen oder kann man dies beliebig an die koerpergroesse anpassen?',
#  'ist bei der tasche auch ein langer tragegurt dabei um sie crossbody tragen zu koennen?',
#  'wie kann die groesse erweitert werden?',
#  'sind die glaeser bei der blauen und gruenen variante auch gruenlich/blaeulich wenn man durchschaut oder nur in der farbe von aussen verspiegelt?',
#  'kann man diese brille auch zum angeln verwenden?',
#  'wie kann ich einen titel zurueckspulen?',
#  'sind sie gut fuer anrufe?',
#  'aus welchen material besteht das produkt?',
#  'wie schuetze ich die karten am besten?',
#  'welche spezialkarten sind bei dem spiel dabei?',
#  'ab welchem alter kann dieses spiel gespielt werden?',
#  'wie kann man des original entfernen?',
#  'gibt es auch eine spuelmascnengeeignete unbescchtete version ?',
#  'ist die flasche innen poliert?',
#  'ist er ein trinkbecher dabei?',
#  'wird der gin in der abgebildeten geliefert?',
#  'welche gewuerze in welcher kombination mit dem passenden tonic koennt ihr empfehlen?',
#  'hat das geraet bluetooth?',
#  'gibt es eine youtubeapp oder muss man ueber den browser gucken?',
#  'kann man damit auch eine leinwand beschriften?',
#  'sind die stifte auswaschbar?',
#  'sind die stifte/farben auch auf hellem untergrund schoen/gut sichtbar?',
#  'sind die farben speichelecht?',
#  'wo kann ich die staebe nachkaufen?',
#  'wie lange dauert die lieferung?',
#  'kann man so staebe nach kaufen?',
#  'ist es ein orginal von apple?',
#  'wo liegt der untersced zwischen diesen airpods und der number euro variante der airpods?',
#  'wie stelle ich bei dem mobile dock die sprache von englisch auf deutsch?',
#  'wieso funktioniert es nicht mit der nintendo switch?',
#  'warum wird mein monitor nur numberhz zeigen?',
#  'funktioniert der adapter auch fuer das mediapad mnumber von huawei?',
#  'besteht die moeglichkeit zwei fahrzeuge gleichzeitig im selben raum fahren zu lassen?',
#  'es leuchtet ein gruenes licht bei dem track kann man das ausschalten?',
#  'werden die kleinen legotechnik motoren verbaut?',
#  'wie bekomme ich den plastik geruch/geschmack am anfang weg?',
#  'wie hoch ist die flasche bei numberml?',
#  'haelt die flasche die getraenke relativ lange kalt?',
#  'kann ich irgendwo einen ersatzteil kaufen?',
#  'wie kann ich die fuellmenge der flasche waehlen?',
#  'wird das sofort umgesetzt oder muss man warten?',
#  'in welcher form wird man ueber einen notwendigen batteriewechsel fuer das thermostat gewarnt?',
#  'habe ich die moeglichkeit direkt am thermostat zwischen automatik und manuellbetrieb umzuschalten ?',
#  'kann man an die dunkelrote mascne auch einen milchschlauch anschliessen?',
#  'muessten nicht normalerweise zwei padas heißtalter mitgeliefert werden?',
#  'ich moechte eine garantie dazu erwerben wie geht das ?',
#  'wirkt der duft der kerze auch gegen rauch?',
#  'riecht sie nach marzipan?',
#  'sind diese farben vegan?',
#  'kann man mit den farben auch marzipan faerben?',
#  'kann man die farbe aus der kleidung auswaschen?',
#  'sind die farben ohne farbstoffe?',
#  'kann ich damit wasser faerben?',
#  'gibt es irgendwo auch eine deutsche anleitung?',
#  'kann ich mehrer thermostate gleichzeitig in einem haus betreiben?',
#  'ist das holster im lieferumfang enthalten?',
#  'passt der schutz auch fuer die vivoactive number musik?',
#  'ist es normal dass\xa0der schlauch nur numbercm lang ist?',
#  'kann das geraet auch ohne schlauch genutzt werden?',
#  'kann man wie bei den vorgaengern auch wieder filteradapter/halter aufkleben bzwanbringen oder ist das nicht mehr moeglich?',
#  'ist die bluetoothverbindung zum handy fuer die uebertragung der gpsdaten stabil?',
#  'wie kann man die uhr kleiner stellen?',
#  'wie lang ist das armband tatsaechlich inkl gehaeuse der uhr?',
#  'kann man das band auch mit einem gewoehnlichen anderen band also von einer anderen marke tauschen?',
#  'wo genau besteht der untersced zum set und zu den sets mit akku oder batterie?',
#  'wieviel buecher/spiele drauf speicherbar?',
#  'ist der tiptoi manager mit apple kompatibel?',
#  'hat der drucker ein extra papierfach fuer anumber und extra eines fuer anumber?',
#  'welche ersatzpatronen passen?',
#  'wie funktioniert der duplexscann?',
#  'wie ist die qualitaet?',
#  'kann man auf dem laptop minecraft spielen?',
#  'laesst sich der ram erweitern?',
#  'wie schwer ist er?',
#  'wie macht sich der untersced zwischen generation number und number bemerkbar?',
#  'brauche ich nur eine bridge pro haushalt?',
#  'koennen die lampen ueber den dimmschalter einzeln angesteuert werden?',
#  'kann man jede lampe mit einer anderen farbe ansteuern?',
#  'kann man wenn man mal keine bunten farben moechte die lampen auch auf ein gutes und angenehmes warmweiss einstellen?',
#  'wie hoch ist die mascne?',
#  'kann man den wassertank abnehmen?',
#  'wie ist die hoehe mit deckel nach oben?',
#  'welche filtertuetengroesse brauche ich fuer die kaffeemascne?',
#  'wie wird es synthetisch hergestellt?',
#  'warum ist es nicht verfuegbar?',
#  'wird dieses msmpulver aus kiefernrinde hergestellt?',
#  'haben kapseln oder das pulver von euch die gleiche wirkung?',
#  'ist die verpackung wieder verschliessbar ?',
#  'verfaerbt es bei kontakt mit schweiss oder wasser?',
#  'ist es in der orginalverpackung?',
#  'wie lange ist die kette insgesamt?',
#  'wie wechselt man die batterie aus?',
#  'gibt es die armbaender in purple und marineblau auch separat zu kaufen ?',
#  'kann man das armband wechseln?',
#  'ist die uhr wasserdicht?',
#  'ist das geraet defekt?',
#  'ist die leistung besser als die der gardenaschere?',
#  'gibt es fuer dieses geraet einen ladekabel zu kaufen?',
#  'kann man die schneidwerkzeuge nachkaufen?',
#  'koennte man damit auch junge brombeertriebe schneiden?',
#  'ist das auch noch was fuer numberjaehrige maedchen?',
#  'ist das putzzeug in kindergroesse oder der normalen groesse?',
#  'ist das fuer so grosse stoffpferde gedacht auf die sich die kinder setzen koennen?',
#  'hat die box keine originale verpackung?',
#  'ist das lovia blutdruckmessgeraet genau?',
#  'ich benoetige ein geraet mit spanischer bedienungsanleitung liegt diese bei?',
#  'werden die daten verloren gehen wenn der akku leer ist?',
#  'was ist der untersced zwischen diesen beiden produkten?',
#  'welche batterie nutzt er und wie gross ist er?',
#  'wird der letzte messwert gespeichert?',
#  'wie kann man die batterie erneuern?',
#  'ist der messsceber komplett aus edelstahl oder nur die scene?',
#  'was ist der untersced zwischen box und ffp?',
#  'kann ich mit dem programm auch die steuer fuer zb number machen?',
#  'kann man er alles fuer die meisterschule eintragen?',
#  'ist die version auch fuer studenten gedacht?',
#  'aus welchem material sind die kuehlsteine gefertigt?',
#  'wie oft kann man die steine wiederverwenden?',
#  'wie bekomme ich die geschmacksneutral?',
#  'inwiefern unterscheiden sich diese?',
#  'wie viele spielstunden hat man ungefaehr?',
#  'ist das spiel identisch mit der wiiu version ?',
#  'wird nur die amiibo von toad unterstuetzt?',
#  'unterstuetzt das spiel den pro controller?',
#  'wird es auf deutsch sein?',
#  'guten tag welche masse haben die rakel?',
#  'welchen uvschutz bietet diese brille?',
#  'ist der schwarze rahmen matt oder glaenzend plastik?',
#  'ist der rahmen aus metall oder kunststoff?',
#  'kann die kamera bei hdraufnahmen die rawdateien mit abspeichern?',
#  'ist die kamera fuers filmen von youtubevideos geeignet?',
#  'ist das filmen auch auf numbergb pro aufnahme beschraenkt?',
#  'wie kann ich bei der eos numberd die aufloesungen auslesen?',
#  'welche groesse passt einem schlanken jungen bei numbernumber koerpergroesse?',
#  'welche kindergroesse entspricht m?',
#  'wie faellt die groesse aus?',
#  'ist der waeschesack auch fuer bettwaesche aus seidensatin geeignet?',
#  'ist das netz auch fuer schuhe geeignet?',
#  'ist der reissverschluss aus metall oder plastik?',
#  'ist das netz auch als trockner geeignet?',
#  'ist ein tunnelverschluss besser?',
#  'kann man das geraet auf die neuste androidversion upgraden?',
#  'welche bluetoothversion hat das tab?',
#  'wie ist es mit der schadstofffreiheit?',
#  'wie lang ist das kabel?',
#  'kann ich den antikalknylonfilter fuer unseren wasserkocher von plips nachkaufen?',
#  'wie lang ist das kabel?',
#  'welchen durchmesser hat die dickste stelle des schlosses?',
#  'ist das schloss auch von kindern zu oeffnen?',
#  'ist das verbindungsstueck zwischen kette und verschlussbolzen aus alugussmaterial ?',
#  'was ist der untersced zwischen speedcross number und speedcross number?',
#  'wie verhalten sich die schuhe auf asphalt?',
#  'hat der schuh eine pronationsstuetze?',
#  'kann das chromebook an einen beamer angeschlossen werden?',
#  'kann man nur in der cloud speichernoder auch alles auf einer externen festplatte speichern?',
#  'kann man mit diesem chromebook auch dokumente ausdrucken?',
#  'kann man in dieses notebook eine groessere ssd einbauen?',
#  'sind die buersten weich mittel oder stark?',
#  'warum hat die aufsteckbuerste vorne und nten eine oeffnung mit rotem ntergrund?',
#  'gibts den helm auch mit klarem visier ?',
#  'passt der helm in das helmfach?',
#  'wie faellt der helm aus?',
#  'ist das visier abnehmbar?',
#  'bewegen sich auch die sterne wenn der marienkaefer an ist?',
#  'dreht sich der sternenmmel?',
#  'kann man die abschaltautomatik auch ausschalten?',
#  'welche abmessungen hat dieser artikel?',
#  'ist der rueckverand kostenlos mit prime?',
#  'ist der teller passend fuer die ikea mikrowelle framtid?',
#  'passt der einsatz in eine panasonic mikrowelle?',
#  'taugt das auch was am motorrad?',
#  'kann ich das navi auch am motorrad nutzen?',
#  'funktioniert das navi gut mit dem iphonex?',
#  'ist es nicht moeglich einen number zoller zu verwenden?',
#  'welchen durchmesser haben die number loecher der wandbefestigung?',
#  'ist die saege made in germany oder auch nur ein weiteres cnaprodukt?',
#  'welches saegeblatt wird mitgeliefert ?',
#  'welche saegeblaetter muss ich mitkaufen?',
#  'kann das handy in der huelle ueber eine qiladestation geladen werden?',
#  'ist der magnet vom verschluss schaedlich fuer die kreditkarten?',
#  'kann das handy durch die huelle kabellos geladen werden oder muss die huelle jedesmal ab?',
#  'warum kein versand nach oesterreich?',
#  'wann gibt es die weisse version?',
#  'ab wann sind die sleeves wieder in weiss erhaeltlich?',
#  'hat das jemand mit diesen er auch?',
#  'welche groesse sollte ich bei nem umfang von numbernumber cm nehmen?',
#  'wann sind die coils wieder vorraetig?',
#  'welche laender sind vorinstalliert?',
#  'bis wieviel volt isoliert?',
#  'gehoert dieser seitenschneider zu den watenfreien bzw facettenfreien seitenschneidern?',
#  'welche hoehe breite tiefe hat der mixer?',
#  'sind die teile spuelmascnengeeignet?',
#  'was ist der untersced ob mit oder ohne cool?',
#  'ist bei dem angebot die trinkflasche dabei?',
#  'kann man das spray auch fuer gummi und dichtungen bei einem cabrio mit stahldach verwenden?',
#  'ist dieses tsrt auch fuer schwimmbaeder geeignet oder zerstoert das chlor die fasern und farbe?',
#  'welche groesse wuerdet ihr bei diesem srt empfehlen?',
#  'wie fallen die hemden aus genau richtig zu klein zu gross?',
#  'wie kann ich es zuruecksccken?',
#  'kann man das tablet auch ohne freetime unlimited nutzen?',
#  'gibt es im kindermodus eine moeglichkeit alle im ntergrund laufenden apps zu beenden?',
#  'ab wann gilt das number jahr amazon freetime unlimited?',
#  'hat das geraet bluethooth?',
#  'ist die feelfit app mit apple health kompatibel?',
#  'wenn die app waehrend des messvorgangs nicht geoeffnet ist werden die daten dann spaeter uebertragen oder verfallen diese?',
#  'wie viele fotos lassen sich mit einer packung machen?',
#  'wie gross sind die bilder ausgedruckt mit und ohne weissen rahmen?',
#  'passen die bilder in den polaroiddrucker?',
#  'kann man auf dem laptop minecraft spielen?',
#  'laesst sich der ram erweitern?',
#  'wie schwer ist er?',
#  'kann man number als stereo betreiben?',
#  'laesst sich das nervtoetende gedudel beim anschalten des geraetes irgendwie abschalten?',
#  'wie kann man das aendern?',
#  'was ist die fluessigkeitskapazitaet des glases?',
#  'wie ist durchmesser der glaeser?',
#  'wie sind die masse der glaeser?',
#  'ist die karaffe eher flach oder quadratisch?',
#  'fuer wieviel kilogramm ist die matratze geeignet?',
#  'liesse sich die matratze trotzdem verwenden?',
#  'was wiegt die matratze?',
#  'ist die matratze aus kaltschaum oder aus einem anderen schaumstoff?',
#  'koennten sie mir die bedienungsanleitung zukommen lassen?',
#  'kann man das geraet auch verwenden wenn man keinen flachen bauch hat?',
#  'kann man die gelpads einzeln nachbestellen?',
#  'kann ich es auch auf englisch umstellen und in den usa benutzen?',
#  'was ist im lieferumfang enthalten?',
#  'kann ich mein up app weiternutzen?',
#  'kann ich mit dem band in die sauna?',
#  'kann man auch nachrichten vom facebook messenger empfangen?',
#  'ist diese mascne unterbaufaeg?',
#  'wird die alte waschmascne mitgenommen?',
#  'wie soll man die mascne vernuenftig in waage aufstellen wenn sie keine hoehenverstellbaren fuesse hat?',
#  'koennen auch tintenpatronen von zb pearl verwendet werden?',
#  'ist der drucker fuer linux/ubuntu geeignet?',
#  'wielang ist die reale akkulaufzeit bei eingeschaltetem gps?',
#  'wie wechsele ich waehrend laufmodus/radfahrmodus auf den musikplayer um die musik lauter zu machen?',
#  'wird das geld direkt abgebucht oder erst nach erscheinung?',
#  'wie kommt man denn an den betakey welcher angepriesen wird?',
#  'brauch ich immer eine internetverbindung?',
#  'wird er auch demnaechst noch die psnumber deluxe version als dvd vorbestellbar sein?',
#  'was passiert wenn die flasche zerbrochen ankommt?',
#  'ist der artikel lange haltbar?',
#  'wie funktioniert versand als geschenk an andere adresse?',
#  'funktioniert der adapter auch mit windows phone?',
#  'was mache ich wenn der adapter nach numbernumber jahren nicht mehr funktioniert?',
#  'kann ich das hdmi kabel mit meinem handy verbinden?',
#  'schaltet sich das geraet automatisch ab?',
#  'kann ich den auch mit warmen wasser aus durchlaufertzer benutzen?',
#  'wie viele fotos lassen sich mit einer packung machen?',
#  'ist das kissen wirklich nur number cm lang?',
#  'ist dieses schwangerschaftskissen komfortabel?',
#  'ist die fuellung auch waschbar?',
#  'gibt es einen zusaetzlichen bezug?',
#  'ist dieses kissen fuer maenner geeignet?',
#  'wann kann ich ungefaehr mit der ware rechnen?',
#  'wie lange dauert die lieferung da der artikel ja nicht auf lager ist?',
#  'welche laenge wuerden sie erfuer empfehlen?',
#  'ist das ende angenaeht?',
#  'wuerden sie auch numberm laenge herstellen?',
#  'wann aeussere ich meine wunschfarbe?',
#  'hat jemand das zelt mal bei etwas staerkerem regen benutzt?',
#  'weiss jemand wo ich die stangen von dem zelt nochmal kaufen koennte da meine defekt sind?',
#  'laesst sich das zelt mit dem feldbett verbinden oder verliert man bei jedem windas heißtauch das dach ueber dem kopf?',
#  'wie hoch ist in etwa die versandsdauer?',
#  'gibt es er eine moeglichkeit?',
#  'welche frequenz sind die toene?',
#  'sollte ich den test morgens machen?',
#  'welches mindesthaltbarkeitsdatum hat der test?',
#  'wird es einen splitscreenmodus geben?',
#  'ist das der feststehende release?',
#  'weiss jemand ob es einen lokalen multiplayer gibt?',
#  'darf der fusssack in den trockner?',
#  'hat jemand erfahrung ob der fusssack passt?',
#  'kann der drucker beidseitig drucken?',
#  'habe ich was falsch gemacht?',
#  'hat der drucker eine lan anschluss?',
#  'kann die durchlaufmenge reguliert werden oder gibt es nur einen ein/aus schalter?',
#  'kann man mit die pumpe auch schmutziges wasser absaugen?',
#  'kann mir jemand den dicksten durchmesser der pumpe sagen bitte?',
#  'macht die pumpe genug druck um damit einen gartenschlauch mit spritze/brause zu benutzen?',
#  'koennte mir vielleicht jemand sagen welchen durchmesser der entchenball hat?',
#  'was ist das bunte in der kugel?',
#  'wo wird das spielzeug hergestellt?',
#  'kommt der test neutral verpackt?',
#  'wird der test so geliefert wie er ist oder im amazon paket?',
#  'laesst sich die farbe leicht von fingern und aus kleidung entfernen?',
#  'kann man die farbe auf stoff haltbar machen sprich einbuegeln?',
#  'wie lange halten die kissen denn?',
#  'was sollen die voreingestellten symbole alle bedeuten?',
#  'welche masse hat die fritteuse?',
#  'ist ein sata kabel enthalten?',
#  'wie enfernt man den die untere plastikscene?',
#  'kann man hantelscheiben nachkaufen?',
#  'wie ist der durchmesser der kurzhantelstange?',
#  'wie lang ist die langhantel?',
#  'ist es moeglich er ein kurzzeitkennzeichen machen zu lassen?',
#  'wo kann ich das kennzeichen angeben?',
#  'sind fuer den preis auch saisonkennzeichen inbegriffen?',
#  'ist dieses geraet wirklich ohne abluftschlauch zu nutzen?',
#  'wie tief ist das geraet einschliesslich direkt senkrecht nach oben gefuehrtem schlauch?',
#  'kann man den auch ohne schlauch als kuehler benutzen?',
#  'ist das geraet wie auf dem bild wirklich schwarz oder auch nur wie die anderen?',
#  'ist die sonnenbrille zu number% verspiegelt?',
#  'bei wem kann ich das reklamieren?',
#  'ist das eine brille fuer schmale gesichter?',
#  'funktioniert der alte smart guide auch bei dieser zahnbuerste oder ist es nur ueber das handy zu verwenden?',
#  'sind druckerkartusche und papier dabei?',
#  'welches zubehoer muss denn noch dazu gekauft werden?',
#  'bis wie viel gb kann man den speicher erweitern?',
#  'kann mann die franzoesische version auch in deutschland benutzen?',
#  'kann ich es dann zuruecksenden ?',
#  'kann man zu zweit spielen?',
#  'gibt es einen untersced zum sims number am pc?',
#  'kann man die sprachausgabe von englisch auf deutsch aendern?',
#  'wieviele karrieren /jobs sind bei sims spielbar?',
#  'wie lange ist das produkt haltbar?',
#  'ist die flasche mit dabei?',
#  'wie lange reicht diese dose ungefaehr?',
#  'kann das jemand bestaetigen?',
#  'zusammen weiss jemand wie hoch der meshfaktor bei diesen kapseln ist?',
#  'ist die hose unten am fuss eng geschnitten?',
#  'ich wart seit letzter woche auf die hose wo kann ich mich da melden?',
#  'welche masse haben die?',
#  'ist die flasche spuelmascnenfest?',
#  'haelt die flasche auch kohlensaeure?',
#  'kann man die huelle waschen?',
#  'warum dauert der versand bis zu number wochen?',
#  'ist es normal dass sich wasser nach jedem bruehvorgamg in der auffangschale sammelt?',
#  'ist es ueblich dass die ausgabe der kaffeereste so nass sind?',
#  'lassen sich auch milchgetraenke programmieren?',
#  'wie lange dauert die ladung wenn sie voll aufgeladen ist?',
#  'ist die powerbank durchladefaeg?',
#  'wie lade ich die powerbank auf?',
#  'ist es auch fuer maenner geeignet?',
#  'wir das haar wirklich laenger und voller?',
#  'wachsen die haare durch die tabletten schneller?',
#  'was fuer wirkungen habt ihr bemerkt?',
#  'stinken die kapseln bei euch auch so?',
#  'kann man damit einen numbertagebart schneiden ohne ihn komplett weg zu rasieren?',
#  'wie ist das mit dem indikator gemeint?',
#  'ist es moeglich den nachzubestellen ?',
#  'kann man jedes headset damit verwenden oder empfehlen sich bestimmte headsets?',
#  'ist es moeglich das programm auf mehreren rechnern laufen zu lassen?',
#  'ist die nagelfeile zu etwas zu gebrauchen?',
#  'hat das messer eine pinzette oder einen zahnstocher?',
#  'ist bei der schwarzen version auch eine huelle dabei?',
#  'heizt das geraet den raum mit angeschaltetem luefter schneller?',
#  'wie lang ist denn das netzkabel?',
#  'ist das geraet auch fuer feuchtraeume geeignet?',
#  'hat jemand fuer das spiel schon eine spielmatte gefunden?',
#  'kann es auch passieren dass gar kein schnittpunkt entsteht?',
#  'ist das spiel geeignet um es mit auf reisen zu nehmen?',
#  'hat jemand jedoch konkrete angaben zum geraeuschpegel?',
#  'wie viel strom verbraucht das geraet?',
#  'kann das geraet seitlich schwenken?',
#  'gibt es bei dieser geldboerse ein seperates fach zum herausnehmen?',
#  'passen auch kreditkarten mit schutzhuelle in die kartenfaecher?',
#  'muss eine niederdruckarmatur installiert werden?',
#  'welche abmessungen hat dieser artikel?',
#  'kann das geraet auch von einem laien angeschlossen werden?',
#  'kann ich das geraet auch ohne fangkorb nutzen?',
#  'ist die luefterwalze dabei?',
#  'ist die messerwalze im lieferumfang enthalten?',
#  'wie stark muss die absicherung in ampere sein?',
#  'ist die schutzhaube per knopfdruck verstellbar?',
#  'ist das spielzeug aus holz oder plastik?',
#  'ist es fuer einen husky geeignet von der groesse her?',
#  'koennen auch katzen damit spielen?',
#  'kann man nach dem zusammenbauen diesen turm auch zwecks reinigung wieder auseinander bauen?',
#  'ist das erscheinungsdatum offiziell?',
#  'wird man das spiel auch als downloadcode vorbestellen koennen?',
#  'ist das ein neuer teil?',
#  'wie viel kw die stunde?',
#  'es sind im lieferumfang ja ein paar kleine schwaemmchen won kommen die denn?',
#  'wie kann ich denn innerhalb der number tage mein geld zurueckbekommen?',
#  'fuer was sind den die gummiringe und die schwaemchen?',
#  'was ist der untersced zwischen den modellen th und yf?',
#  'funktioniert die geschwindigkeitsmeldung einwandfrei?',
#  'kann man die kamera wirklich noch in die hosentasche stecken?',
#  'sind die baelle sehr hart?',
#  'was fuer haertegrad hat der ball?',
#  'gibt es den ball auch in einer weicheren qualitaet?',
#  'gibt es ueberhaupt aufsteckbuersten mit kleinerem kopf fuer oral b pulsonic?',
#  'ich moechte den strauss am numbernumber liefern lassen wie funktioniert das?',
#  'kann man die auch in schwarz bestellen?',
#  'kann man die lichterkette auch gegen eine andere austauschen?',
#  'wie gross ist eines der geometrischen formen?',
#  'warum steht er prime und dann werden doch versandkosten berechnet?',
#  'funktioniert der adapter auch in mexiko?',
#  'geht dieser stecker auch in der dom rep?',
#  'ist der stecker auch fuer japan/ tokio geeignet?',
#  'ist das die wasserwaage mit dem griff?',
#  'was koennte das problem sein?',
#  'haben die mannschaften der dritten liga in deutschland die original kader oder sind die namen zufaellig?',
#  'warum ist der liefertag erst am numbernumber?',
#  'ist das spiel auch auf englisch?',
#  'welche toene gibt es genau?',
#  'wuerde mir jemand die komplette deutsche gebrauchsanleitung zukommen lassen?',
#  'wie aendert man von englischer zeitangabe in die deutsche zeitangabe?',
#  'wie ist die soundqualitaet zum alten echo?',
#  'kann man das amazon service mit alexa auch in anderen laendern verwenden?',
#  'gibt es bereits eine reaktion seitens amazon nsichtlich der zahlreichen schlechten bewertungen des klangs?',
#  'mit welchem mittel bekomme ich die am besten raus?',
#  'wie wird die obere klappe gehalten?',
#  'verfaerbt sich die tasche bei regen?',
#  'welche gewuerze in welcher kombination mit dem passenden tonic koennt ihr empfehlen?',
#  'schwitzt deine haut unter der band?',
#  'da es magnetisch ist gibt es ein problem es in der naehe von handys zu haben?',
#  'koennt ihr uns helfen?',
#  'ist das spiel auch fuer farbenblinde geeignet?',
#  'ist die gebrauchsanweisung in deutsch?',
#  'ab wieviel jahren ist das spiel?',
#  'welche instrumente genau sind in diesem programm enthalten?',
#  'ist das programm kompatibel mit win number?',
#  'kann man die musik die man macht auch speichern?',
#  'wie kann ich einen verschluesselten sender entschluesseln?',
#  'funktioniert der receiver auch bei kabelbw?',
#  'mit welchem betriebssystem wird denn jetzt ausgeliefert?',
#  'funktioniert die uhr mit dem samsung jnumber?',
#  'was soll ich tun ?',
#  'ist das produkt frei von weichmachern ?',
#  'ist bei der lieferung eine tonerkartusche dabei?',
#  'kann ich auch kopieren mit dem geraet?',
#  'nterlaesst das gelpad rueckstaende auf dem armaturenbrett?',
#  'welche version war das?',
#  'was ist noch dabei in der ultimate edition im vergleich zu der special edition?',
#  'wird man das spiel auf der playstation number pro in numberk spielen koennen?',
#  'wie breit ist die schnalle?',
#  'bezieht sich die groesse auf die glasflaeche oder den ganzen rahmen?',
#  'kann man den bilderrahmen waagerecht und senkrecht verwenden?',
#  'ist die farbe stahl einfach nur ein dunkles grau?',
#  'welche systemanforderungen hat das spiel?',
#  'gibt es auch eine collectors edition ?',
#  'welche systemanforderungen benoetigt das spiel?',
#  'bekommt man ein hardcover dazu?',
#  'welche systemfoerderung braucht das spiel?',
#  'kann man diese lampe auch im laufenden betrieb laden?',
#  'welche batterien werden benoetigt?',
#  'ist sie dunkel genug dass sie die partnerin beim schlafen nicht stoert?',
#  'ist der duschkopf auch fuer durchlaufertzer geeignet?',
#  'ist die handbrause auch fuer gas thermen geeignet?',
#  'ist dieser er gegeben?',
#  'wie viele seiten schaffen die ersten mitgelieferten toner?',
#  'was ist zu tun?',
#  'ist es ein reiner reboarder oder kann man ihn auch in fahrtrichtung befestigen?',
#  'laeuft das spiel auch auf windows number?',
#  'laeuft die version auch auf mac?',
#  'wie lange dauert es bis man den code zugesendet bekommt?',
#  'auch zum locken machen geeignet?',
#  'wie lange habe ich garantie auf das geraet wenn ich es er ueber amazon kaufe?',
#  'muss ich die temperatur jedes mal einstellen oder bleibt sie vom letzten mal gespeichert?',
#  'kann ich locken mit diesem geraet machen?',
#  'kann man ihn waschen?',
#  'hat dieser dunkelblaue rucksack ebenfalls einen brustgurt?',
#  'hat der rucksack einen brustgurt?',
#  'wie montierte ich die raeder?',
#  'wie sind die masse der tasche?',
#  'wie bekomme ich die stange fuer die raeder durch?',
#  'was kostet der rueckversand?',
#  'bis zu welcher hemdengroesse ist er geeignet?',
#  'gibt es das kaffee und den filter dazu oder war es nur ein einmaliges angebot?',
#  'kann man auch einen dauerfilter verwenden anstatt papierfilter?',
#  'was fuer ein mahlwerk ist er verbaut?',
#  'wann ist bitte diese kaffeemascne mit thermoskanne und abnehmbaren wassertank wieder verfuegbar?',
#  'wie steht es um eine garantie?',
#  'was hat die flasche fuer eine fuellmenge?',
#  'kann die flasche mit silikonhuelle in den gescrrspueler?',
#  'kann man den schraubverschluss separat nachbestellen?',
#  'sind die deckel giftig verarbeitet?',
#  'wie bekomme ich den deckel von innen sauber?',
#  'kann man die leds austauschen?',
#  'ist diese lampe dimmbar?',
#  'ist die lampe auch fuer das badezimmer geeignet?',
#  'ist es aus glas oder plastik ?',
#  'ist das layout der tastatur in deutsch?',
#  'kann man eine maus an die tastatur anschliessen?',
#  'wann ist die uhr in der farbe grau und schwarz wieder verfuegbar ?',
#  'sind die metallic uhren auch fuer schmale handgelenke geeignet?',
#  'kann man die uhr selbst oeffnen?',
#  'ist die uhr nickelfrei?',
#  'wie viele personen koennen ueber eine lizenz bearbeitet werden?',
#  'was ist denn in der dicken verpackung drin?',
#  'kann man mit dem code die testversion freischalten?',
#  'ist die mascne selbstkuehlend?',
#  'passt der behaelter in das gefrierfach einer kuehlgefrierkombi?',
#  'kann man in der mascne auch softeis in der art von mcflurry herstellen?',
#  'gibt es eine alternative zu dem teuren wasserfilter?',
#  'wieviele jahre haelt das kegelwerk in etwa?',
#  'wie hoch und wie tief ist das geraet wirklich?',
#  'kann man damit auch fluessigkeit in ml wiegen?',
#  'hat\xa0die\xa0waage\xa0eine\xa0abschaltautomatik?',
#  'laesst sich die platte zur reinigung abnehmen?',
#  'hat dieser ofen ein backblech?',
#  'passt da eine normale pizza rein?',
#  'was wiegt der pizzaofen?',
#  'sind das jetzt buntstifte oder filzstifte?',
#  'ab welchem alter genau machen diese stifte sinn?',
#  'kann man mit dem dekostiften auch auf holz malen?',
#  'welche papierkassette fuer number blatt kann ich dazu bestellen?',
#  'wie viel papier fasst der drucker und kann er aufgeruestet werden?',
#  'wo bekommt man eine komplette gebrauchsanleitung her?',
#  'wird der drucker mit tonerpatronen geliefert?',
#  'wie macht er das?',
#  'kann man das spiel auch ohne app spielen?',
#  'lohnt es sich die number edition zu kaufen wenn man bereits die number edition hat?',
#  'kann man die erweiterung die es dazu gibt auch alle gleichzeitig mit dem standard spiel spielen ?',
#  'macht es auch spass wenn man es alleine spielt?',
#  'was ist an der select speicherkarte anders als an der plus?',
#  'was bedeudet bei speicherkarten die bezeichnung unumber?',
#  'was ist der klare untersced zur klassischen evo plus serie von number?',
#  'piepst das geraet wenn der knopf gedueckt wird oder wenn es fertig ist ?',
#  'aus welchem material besteht das kleine plastikteil am quirl ?',
#  'wieso leuchtet er nach ein paar tagen nicht mehr?',
#  'kann man die temperatur anzeige von fgrad auf cgrad umstellen ?',
#  'wie schalte ich denn den klingelnden wecker aus?',
#  'was muss ich machen damit die gestellte alarmzeit auch aktiviert wird?',
#  'kann sich das geraet mit versteckten wlans verbinden?',
#  'muss ich fuer number artikel dreimal porto bezahlen?',
#  'kann man mit dem geraet auch kopieren?',
#  'kann ich mit dem geraet verscedene papierformate drucken?',
#  'wird es eine collectors edition geben ?',
#  'laesst sich das lederband auch wechseln?',
#  'ist die farbe rosegold oder gold?',
#  'gibt es diese denn einzeln zu kaufen?',
#  'habe ich garantie da die uhr defekt ist?',
#  ...]

# %%
# #############################################################################
# Define a pipeline combining a text feature extractor with a simple
# classifier
import xgboost as xgb

pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
    ('clf', LinearSVC()),
    #('clf', xgb.XGBClassifier(max_depth=5, n_estimators=100, learning_rate=0.125, min_child_weight = 1)),
])

# %%
# uncommenting more parameters will give better exploring power but will
# increase processing time in a combinatorial way
parameters = {
    'vect__max_df': (0.5, 0.75, 1.0),
    #'vect__max_features': (None, 5000, 10000, 50000),
    'vect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    #'tfidf__use_idf': (True, False),
    #'tfidf__norm': ('l1', 'l2'),
    #'clf__max_depth': (5, 6),
    #'clf__n_estimators': (100, 150),
    #'clf__learning_rate': (0.1, 0.125),
    #'clf__min_child_weight':(1, 2)
    #'clf__n_iter': (10, 50, 80),
}

# %%
if __name__ == "__main__":
    # multiprocessing requires the fork to happen in a __main__ protected
    # block

    # find the best parameters for both the feature extraction and the
    # classifier
    grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1, verbose=1)

    print("Performing grid search...")
    print("pipeline:", [name for name, _ in pipeline.steps])
    print("parameters:")
    pprint(parameters)
    t0 = time()
    grid_search.fit(data_frame[0], data_frame[1])
    print("done in %0.3fs" % (time() - t0))
    print()

    print("Best score: %0.3f" % grid_search.best_score_)
    print("Best parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
