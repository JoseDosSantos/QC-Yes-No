# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np
import Classification.config as cfg
import csv
import nltk
import random
import re
import warnings
from sklearn.metrics import accuracy_score
warnings.filterwarnings('ignore')

# %%
def clean(string):
    clean_string = re.sub(r'\d+', '+number+', string)
    clean_string = re.sub(r'"', '', clean_string)
    clean_string = re.sub(r'\s{2,}', ' ', clean_string)
    clean_string = re.sub(r'\s\?', ' ', clean_string)
    return clean_string.lower()

# %%
data_set = []
for file in cfg.ALL_FILES:
    reader = csv.reader(open(file, 'r'), delimiter=';')
    for line in reader:
        data_set.append([clean(line[0]), line[1]])

# %%
data_set
# Out:
# [['warum so lange gewartet mit anschauen?', '0'],
#  ['trauen sie sich?', '1'],
#  ['fangen wir mit den doppelten werten an und arbeiten uns weiter vor?', '1'],
#  ['sehr kreativ die jungs nicht?', '1'],
#  ['hey wollen wir morgen was machen?', '1'],
#  ['aber sinkt die rente überhaupt immer weiter?', '1'],
#  ['und die tänzerin war doch legendär, oder?', '1'],
#  ['wie variabel nutzen die deutschen ihre passwörter?', '0'],
#  ['sollten wir nicht irgendwas machen?', '1'],
#  ['wo kann man das kaufen?', '0'],
#  ['warum nicht im osten mit koalieren?', '0'],
#  ['auf was soll ich stolz sein?', '0'],
#  ['cola ohne zucker, mit synthetischem ersatzstoff?', '1'],
#  ['gegen wen hetzt sie?', '0'],
#  ['und wo schürt sie ängste?', '0'],
#  ['nizza will ballotelli wieder verkaufen?', '1'],
#  ['brauchen die muppets noch personal?', '1'],
#  ['hat er eigentlich eine klimaanlage?', '1'],
#  ['und was habt ihr so diesen sommer gemacht?', '0'],
#  ['was machst du auf der männertoilette?', '0'],
#  ['hyperventiliert der noch immer?', '1'],
#  ['was wäre die welt ohne senioren ', '0'],
#  ['wieviele opfer muss es noch geben?', '0'],
#  ['wievie leid müssen die angehörigen noch ertragen?', '0'],
#  ['eine beziehung ohne küssen und ohne, dass man sich mal getroffen hat?',
#   '1'],
#  ['brauchst du für die kommenden tage welche?', '1'],
#  ['ab wann beginnt die college football saison?', '0'],
#  ['welche konzerne?', '0'],
#  ['könnt ihr resetten?', '1'],
#  ['hat vielleicht noch irgendwer +number+ tickets für den gc samstag?', '1'],
#  ['welche kriterien muss man dafür denn erfüllen?', '0'],
#  ['wie viel verdiene ich mit youtube?', '0'],
#  ['renderzentrale dann gleich neben rewe?', '0'],
#  ['kennt jemand den oder die malerin dieses bildes?', '1'],
#  ['ach, wie schön ist das denn?!', '0'],
#  ['was ist da los?', '0'],
#  ['fällt das unter wahnvorstellungen eines irsinnigen?', '1'],
#  ['wovon willst du etwas stehlen?', '0'],
#  ['was noch passieren muss?', '0'],
#  ['ihr wollt noch ein ticket für die gamescom (donnerstag)?', '1'],
#  ['ihr hättet auch gerne einen zuhause?', '1'],
#  ['was ist das?', '0'],
#  ['was tun wir da?', '0'],
#  ['wieso gehen wir da hin?', '0'],
#  ['und dazu nudeln ohne tüte?', '1'],
#  ['kommst du bei uns vorbei?', '1'],
#  ['bin ich eigentlich der einzige, der sich einfach mal so gar nicht für danny williams interessiert hat?',
#   '1'],
#  ['na was hat sie da zu suchen?', '0'],
#  ['wer bietet mehr?', '0'],
#  ['hab ich das gerade richtig im radio gehört?', '1'],
#  ['welches computerspiel das internet in deutschland maßgeblich geprägt?',
#   '0'],
#  ['hat wer meine motivation gesehen?', '0'],
#  ['kennt doch jeder, oder?', '1'],
#  ['wie alt bist du?', '0'],
#  ['wie lange hats gedauert?', '0'],
#  ['sollte man nähe denn erzwingen?', '1'],
#  ['wo muss ich unterschreiben?', '0'],
#  ['welches land wird in zukunft deutschlands wichtigster verbündeter sein?',
#   '0'],
#  ['wann ist deine nächste party?', '0'],
#  ['warum kannst du nicht weiblich sein?', '0'],
#  ['was macht ihr am samstag?', '0'],
#  ['hey, wollt ihr uns verarschen?', '1'],
#  ['brauchst du ein hustenbonbon?', '1'],
#  ['warum bin ich nur so gesetzestreu?', '0'],
#  ['was steht da?', '0'],
#  ['alles wie immer?', '1'],
#  ['trauen sie sich?', '1'],
#  ['wann gibt es anlass, die strategie zu ändern?', '0'],
#  ['brauchst du noch was?', '1'],
#  ['soll ich dir was bringen?', '1'],
#  ['was dann passiert?', '0'],
#  ['du kannst einfach das ganze video mit werbung kennzeichnen oder?', '1'],
#  ['panische angst vorm zahnarzt?', '1'],
#  ["hast du nicht bald'n kind?", '1'],
#  ['und wisst ihr, was das allerschlimmste an elternabenden ist?', '1'],
#  ['wie kriegt man sowas hin?', '0'],
#  ['ist mir gerade ein kartoffelchip runter gefallen?', '1'],
#  ['sie sind +number+?', '1'],
#  ['aber was ist denn nun eigentlich gesund, woran kann man das erkennen?',
#   '0'],
#  ['tradevisitor kann man kaufen?', '1'],
#  ['warum trinken fußballfans eigentlich immer alles mit milch?', '0'],
#  ["wer hat's erfunden?", '0'],
#  ['wie kann man dieses eis nicht lieben?', '0'],
#  ['schon gewusst?', '1'],
#  ['da darf man innen drin noch rauchen?', '1'],
#  ['hörst du diese töne?', '1'],
#  ['was kann ich für sie tun?', '0'],
#  ['auf welchem kanal?', '0'],
#  ['schmeckt er denn genauso?', '1'],
#  ['was ist da los?', '0'],
#  ['du findest es also ok, wenn ein spieler seinen verein erpresst?', '1'],
#  ['wen meinen sie mit landsleuten?', '0'],
#  ['bin gerade in halle +number+, jemand zum quatschen da?', '1'],
#  ['was ist in der stadt los?', '0'],
#  ['gibt es das auch bei chefkoch?', '1'],
#  ['ja, aber helfen sie auch?', '1'],
#  ['wovon träumst du gerade?', '0'],
#  ['welche partei hat ihrer meinung nach die größte kompetenz in der migrations- und integrationspolitik?',
#   '0'],
#  ['etwa bei der gez?', '1'],
#  ['wie kann ein popstar nach einem terroranschlag weitersingen?', '0'],
#  ['ausbildungsvertrag in der hand, aber was kommt danach?', '0'],
#  ['wer kennt das?', '0'],
#  ['du bist hindu oder?', '1'],
#  ['weisst du eigentlich, dass du extrem hübsch bist?', '1'],
#  ['du würdest die menschen auf der straße leben und verhungern lassen?', '1'],
#  ['wie gut ist die grafik wirklich in black ops +number+?', '0'],
#  ['wie sah das aus?', '0'],
#  ['argumentiert die wissenschaft für oder gegen die existenz gottes?', '0'],
#  ['war er jetzt da oder kam er zu spät?', '0'],
#  ['und da wundert ihr euch noch, dass so viele menschen lieber das auto nehmen?',
#   '1'],
#  ['wie kann man seinem mann nur so in den rücken fallen?', '0'],
#  ['wie kommt man da denn bloß hin?', '0'],
#  ['upgrade gefällig?', '1'],
#  ['wer gehört neben chopin zu den fünf bedeutendsten komponisten polens?',
#   '0'],
#  ['du hast sechs zehen?', '1'],
#  ['dürfen wir mal einen ausprobieren?', '1'],
#  ['arbeitet photoshopphilliph jetzt für euch?', '1'],
#  ['was denn nun?', '0'],
#  ['wofür?', '0'],
#  ['wen soll ich mitnehmen?', '0'],
#  ['schon gewusst?', '1'],
#  ['du möchtest dauerhaft erfolgreich sein?', '1'],
#  ['wo sind die arctic monkeys-begeisterten?', '0'],
#  ['was macht stürmer klaus drachau heute?', '0'],
#  ['was gibt ihnen anlass zu dieser unterstellung?', '0'],
#  ['wo ist der unterschied?', '0'],
#  ['und das fällt erst heute auf?', '1'],
#  ['alles gut mit dir?', '1'],
#  ['blöde frage, aber wie kriege ich den auf?', '0'],
#  ['sind die jetzt total übergeschnappt?', '1'],
#  ['warum hat man sich dann so energisch gegen einen untersuchungsausschuss gewehrt?',
#   '0'],
#  ['wieso komme ich mit meinen gedanken nicht von dir weg?', '0'],
#  ['sind das die +number+ guten würfe in folge, an denen ich hänge?', '1'],
#  ['es gibt menschen, die das nicht tun?', '1'],
#  ['bro kann ich mitspielen?', '1'],
#  ['du auch?', '1'],
#  ['kann präsident trump sich wirklich selbst begnadigen?', '1'],
#  ['rollenmodelle, prozesslandkarten und immobilienorganisation sind für dich routine?',
#   '1'],
#  ['wie werden sie in der praxis angewendet?', '0'],
#  ['mit +number+ euro weniger im portemonnaie gleich pleite?', '1'],
#  ['ist auf deinen tickets ein bild vom albumcover?', '1'],
#  ['du suchst gute mitspieler, oder willst einfach mal mit den pros reden?',
#   '1'],
#  ['liegt giftmüll in osnabrücks unterwelt?', '1'],
#  ['und wie ist der aktuelle umrechnungsfaktor?', '0'],
#  ['könnten wir den ausprobieren, bevor wir ihn kaufen?', '1'],
#  ['vorgezogene koalitionsverhandlungen im tv?', '1'],
#  ['wer wohnt in `ner ananas ganz tief im sand?', '0'],
#  ['was kosten aids medikamente pro person im jahr?', '0'],
#  ['habt ihr schon mal bei +number+° ein +number+.+number+ qm großes maislabyrinth erwandert?',
#   '1'],
#  ['stellen wir uns diesmal an?', '1'],
#  ['könntest du mir da mal einen link schicken oder so?', '1'],
#  ['kostic-debüt schon samstag in freiburg?', '1'],
#  ['wer denn sonst?', '0'],
#  ["wo geht's hin?", '0'],
#  ['verstehe ich das richtig?', '1'],
#  ['haben sie die dame darauf angesprochen?', '1'],
#  ['wer zur hölle denkt sich solche klassifizierungen aus?', '0'],
#  ['warum haben sie da zwei schweißnähte?', '0'],
#  ['wer noch?', '0'],
#  ['warum nur wasser?', '0'],
#  ['werden sie verdrängt?', '1'],
#  ['oder werden sie verdrängen?', '1'],
#  ['du willst doch wohl nicht tamers und powerrangers spin-offs vergleichen?',
#   '1'],
#  ['was fang ich mit ihrem beitrag an?', '0'],
#  ['was mache ich denn mit so viel freier zeit?', '0'],
#  ['wollt ihr schon verraten wer kommt?', '1'],
#  ['warum redest du immer so abgeklärt über dinge, die mir so wichtig sind?',
#   '0'],
#  ['gilt die leseempfehlung auch für männer?', '1'],
#  ['vielleicht fängt er jetzt mal an sich zu informieren?', '1'],
#  ['was muss man als neuer account machen, um entdeckt zu werden?', '0'],
#  ['wer hat sie schon?', '0'],
#  ['wer bin ich?', '0'],
#  ['soll der mann hier etwa in eine freie und besetzbare planstelle eingewiesen werden?',
#   '1'],
#  ['wer hat noch nicht, wer will nochmal?', '0'],
#  ['vielleicht beim nächsten mal?', '1'],
#  ['flüchtlinge, die einen job haben, abschieben?', '1'],
#  ['wo bleibt eigentlich die zuverlässigkeit?', '0'],
#  ['wer sagt denn dass ich herumalbere?', '0'],
#  ['was ist das für ein benutzungspflichtiger radweg?', '0'],
#  ['wofür geht man +number+-+number+ jahre studieren, wenn man dann immer nur auf verbote pocht?',
#   '0'],
#  ['ach wieso ist das peinlich?', '0'],
#  ['kannst du mir mal eine dm schreiben?', '1'],
#  ['was ist der unterschied zwischen einem chemiker und einer hebamme?', '0'],
#  ['weißt du dazu mehr?', '1'],
#  ['wie sieht das ab +number+ märz aus?', '0'],
#  ['irgendwer lust auf salmon run?', '1'],
#  ['was wurde verstaatlicht?', '0'],
#  ['wie sollte es manche strecke sonst überwinden?', '0'],
#  ['was ist denn das?', '0'],
#  ['was hat die schon wieder auf der gamescom zu suchen?', '0'],
#  ['welche sprache darf es sein?', '0'],
#  ['für immer weg?', '1'],
#  ['gibt es schließfächer auf dem gelände, damit ich nicht alles rumschleppen muss?',
#   '1'],
#  ['wie bitte?', '0'],
#  ['welcher bürger sollte davon einen vorteil haben?', '0'],
#  ['ist die abschiebung nicht schon in den +number+ern beschlossen worden?',
#   '1'],
#  ['und wo kommt dann das wasser her?', '0'],
#  ['alles wie immer?', '1'],
#  ['lohnt sich ein philosophiestudium?', '1'],
#  ['eine homage an peter lustig?', '1'],
#  ['wie nett ist denn bitte das album?', '0'],
#  ['die rettung der flüchtlinge im #mittelmeer ist also illegal?', '1'],
#  ['wann fährst du zurück?', '0'],
#  ['habt ihr auch einen schönen sonnenauf- oder untergang fotografiert?', '1'],
#  ['nice, wo gibt es sowas?', '0'],
#  ['wieso war eigentlich +number+ jahre lang kein deutscher außenminister in auschwitz?',
#   '0'],
#  ['ozeane - rohstoffquelle der zukunft?', '1'],
#  ['was halten wir davon?', '0'],
#  ['ist das sinnvoll?', '1'],
#  ['was müsst ihr machen?', '0'],
#  ['darf das ein arbeitgeber?', '1'],
#  ["gibt's die hose auch in kurz?", '1'],
#  ['was haben unterschiedliche steuersysteme mit fairer marktwirtschaft zu tun?',
#   '0'],
#  ['heute dann ohne wespe?', '1'],
#  ['was tun?', '0'],
#  ['macht ihr was?', '1'],
#  ['was war denn?', '0'],
#  ['was ist eigentlich ironie?', '0'],
#  ['und was ist sarkasmus?', '0'],
#  ['ach und warum redest du englisch?', '0'],
#  ['welcher beruf?', '0'],
#  ['wie weit bist du da schon?', '0'],
#  ['du kannst auf wände klettern?', '1'],
#  ['hat jemand noch eine karte für samstag bei der gamescom zu verkaufen?',
#   '1'],
#  ['wie funktioniert polizei hier in berlin?', '0'],
#  ['was machst du da?', '0'],
#  ['sind denn dieses mal wieder die kryptominer schuld?', '1'],
#  ['lese ich da richtig?', '1'],
#  ['wie fandest du lego super villains?', '0'],
#  ['gibt es das auch in der halle +number+ bei warner?', '1'],
#  ['dann solltest also du entscheiden dürfen wie radikal es sein darf?', '1'],
#  ['oh, haben sich +number+ gefunden?', '1'],
#  ['möchtest du beim gewinnspiel mitmachen und mich unterstützen?', '1'],
#  ['hast du bereits eine störung gemeldet?', '1'],
#  ['nur was wäre dein vorschlag?', '0'],
#  ['woran liegt das?', '0'],
#  ['war es gut?', '1'],
#  ['was ist mit der atemluft in den städten, vor allem in münchen?', '0'],
#  ['spricht meine marke die sprache meiner kunden?', '1'],
#  ['und hab ich überhaupt kunden?', '1'],
#  ['gibt es schließfächer auf dem gelände?', '1'],
#  ['was ist denn daran so lustig?', '0'],
#  ['denkst du dass es der signal iduna park war?', '1'],
#  ['und jetzt ist ihr tweet weg?', '1'],
#  ['hast du hobbies?', '1'],
#  ['ist das die rolltreppe nach pankow?', '1'],
#  ['ist das denn inzwischen einigermaßen gesichert?', '1'],
#  ['du bist auf der gamescom?', '1'],
#  ['kann man dich heute noch irgendwo sehen?', '1'],
#  ['schmetterlinge sind doch eigentlich auch nur geflügelte würmer oder?', '1'],
#  ['was ist das ziel der aktionstandesamt+number+?', '0'],
#  ['welche insel ist das?', '0'],
#  ['netflix and chill?', '1'],
#  ['und warum kam es so?', '0'],
#  ['erneute leihe nach holland?', '1'],
#  ['läuft da was?', '1'],
#  ['was geht bei euch?', '0'],
#  ['wer darf moderationen bei der industrie machen?', '0'],
#  ['bist du jetzt automatisch teil des raiffeisen-konsortiums?', '1'],
#  ['warum nur +number+?', '0'],
#  ['wie heißen diese dunkleren, glänzenden fussfettverfärbungen in birkenstock schuhen nochmal auf englisch?',
#   '0'],
#  ["wie geht's dir eigentlich?", '0'],
#  ['ist heut schon wieder gegenteiltag?', '1'],
#  ['sicher?', '1'],
#  ['an welchen tagen bist du da ', '0'],
#  ['ist das nicht ein bisschen kalt?', '1'],
#  ['welcher wind ist denn gemeint ', '0'],
#  ['würden sie unter diesen voraussetzungen eine lesung in hagen machen?', '1'],
#  ['wie komm ich jetzt nach ehmen?', '0'],
#  ['was ist das für ein trend?', '0'],
#  ['inwiefern fördert eine badeanzug bitte unsere freiheit?', '0'],
#  ['darf ich ein bild von mir mit meiner neuen frisur hochladen?', '1'],
#  ['bei euch auch?', '1'],
#  ['welche behauptung genau ist denn sachlich falsch?', '0'],
#  ['führt der klimawandel zu mehr hochs?', '1'],
#  ['wie weit kann die erholung beim eurusd noch gehen?', '0'],
#  ['ihr wollt ein headset mitsamt einer maus gewinnen?', '1'],
#  ['wer bitte sollte diese menschen einstellen?', '0'],
#  ['auch dann endlich mit erfolgen?', '1'],
#  ['wer hat euch verraten?', '0'],
#  ['sprang britin über die reling nach streit?', '1'],
#  ['kann sie sprechen?', '1'],
#  ['was hampeln die denn da rum?', '0'],
#  ['wie kannst du das nur von mir denken?', '0'],
#  ['haben sie ein augenproblem?', '1'],
#  ['wieso bedeutet suv automatisch immer schlecht?', '0'],
#  ['trailer zu the journey schon gesehen?', '1'],
#  ['wie soll das denn noch zwei tage weitergehen?', '0'],
#  ['weißt du welche spedition es fährt?', '1'],
#  ['sind wir nicht alle ein bisschen anders?', '1'],
#  ['wer bezeichnet ihn als experten, außer er sich selbst?', '0'],
#  ['wer kennt dieses spiel?', '0'],
#  ['was ist denn das schanzenfest?', '0'],
#  ['was ist denn das?', '0'],
#  ['irgendwer am kölner dom?', '1'],
#  ['werden die college football spiele bei dazn gezeigt?', '1'],
#  ['ja gut, aber warst du es?', '1'],
#  ['wer wird zukünftig diesen job noch machen?', '0'],
#  ['wo ist der bus?', '0'],
#  ['wozu braucht es fischer, wenn es gerichte schon taten?', '0'],
#  ['herz, wie stellst du dir das denn vor?', '0'],
#  ['merkt ihr selber, ne?', '1'],
#  ['ist etwas passiert?', '1'],
#  ['kann man irgendwie für dich da sein?', '1'],
#  ["wen wundert's noch?", '0'],
#  ['noch fragen?', '1'],
#  ['kommst du heute abend zum grillen in den garten?', '1'],
#  ['ist das überdacht?', '1'],
#  ['habt ihr auch solche lieblingsorte in münchen?', '1'],
#  ['was denn nun?', '0'],
#  ['wie plant man eine barrierefreie veranstaltung?', '0'],
#  ['ihr wollt bei der nächsten auslosung live dabei sein?', '1'],
#  ['was soll das denn?', '0'],
#  ['was macht man als pr-berater so?', '0'],
#  ['warum denk ich an geiselnahme, wenn ich das lese?', '0'],
#  ['also wo könnte man denn eine bewerbung abgeben?', '0'],
#  ['wie krank ist das denn?', '0'],
#  ['was willst du denn bitte mehr im leben?', '0'],
#  ['man kann seine handyrechnung von der steuer abziehen?', '0'],
#  ['habt ihr wieder verdacht, ja?', '1'],
#  ['was soll daran schlimm sein?', '0'],
#  ['was bereust du?', '0'],
#  ['ist das nicht schon seit jahren satire, was dieser account twittert?', '1'],
#  ['so oder ähnlich muss ich das verstehen?', '1'],
#  ['vegan?', '1'],
#  ['hast du vielleicht ein rezept?', '1'],
#  ['könnte die schildkröte eventuell spuren von plutonium enthalten?', '1'],
#  ['help, worum gehts hier eigentlich?', '0'],
#  ['wie lange dauert es in der regel, bis es wieder funktioniert?', '0'],
#  ['warum eigentlich heißt ihr als nischenanbieter noch spiegel?', '0'],
#  ['es wird nie aufhören, oder?', '1'],
#  ['was läuft denn jetzt so auf netflix?', '0'],
#  ['verstehst du?', '1'],
#  ['was ist das geheimnis des deutschen mittelstandes?', '0'],
#  ['warum ist am ende der nerven eigentlich immer noch so viel waches, singendes kleinkind übrig?',
#   '0'],
#  ['den euro retten aber wie?', '0'],
#  ['solltest du nicht schon im bett sein?', '1'],
#  ['hey, da waren wir doch, oder?', '1'],
#  ['das internet ist schon ein fieses bierzelt, nicht wahr?', '1'],
#  ['entschuldigung, was hat der elternvertreter nicht verstanden?', '0'],
#  ['wer hat mich beschworen?', '0'],
#  ['lust auf ein gutes, spannendes und packendes buch?', '1'],
#  ['muss ich etwa vorbeikommen?', '1'],
#  ['warum sind journalisten eigentlich der meinung über recht und gesetz zu stehen?',
#   '0'],
#  ['was macht sie denn so zornig?', '0'],
#  ['warum sollte es denn deiner meinung nach keine kinder in lokalen geben?',
#   '0'],
#  ['du liebst motorräder?', '1'],
#  ['wegen dem training, oder wegen dem foto?', '0'],
#  ['was heißt wirken?', '0'],
#  ['oder ruhen deine gedanken auch mal aus?', '1'],
#  ['was denkst du denn?', '0'],
#  ['hattest du auch eine op um die gesichtszüge anzugleichen?', '1'],
#  ['ist das denn jugendfrei, was ihr jeden abend so macht?', '1'],
#  ['ist das spiel noch schlechter als fifa +number+?', '1'],
#  ['gibts den anstoßbug noch?', '1'],
#  ['bin ich gerade der einzige?', '1'],
#  ['warum sagt da keiner was zu?', '0'],
#  ['wie oft ist das schon in deutschland passiert?', '0'],
#  ['wer ist das?', '0'],
#  ['hatte weinstein das nicht genauso gemacht?', '1'],
#  ['wie heißt du denn da?', '0'],
#  ['gibt es eigentlich lady gaga noch?', '1'],
#  ['du suchst deine erfüllung?', '1'],
#  ['bin ich schon so alt?', '1'],
#  ['können sie diesen unsinn belegen?', '1'],
#  ['oh je ist denn alles wieder in ordnung?', '1'],
#  ['geht es dir besser?', '1'],
#  ['gibt es eine möglichkeit, es auch an anderen schulen anzubieten?', '1'],
#  ['wo kommst eigentlich her?', '0'],
#  ['ist das nicht gefährlich?', '1'],
#  ['was will mir das leben mitteilen?', '0'],
#  ['worauf will sie nicht zurückblicken?', '0'],
#  ['was macht ihr heute noch ', '0'],
#  ['denkst du denn, dass du trotzdem damit leben könntest?', '1'],
#  ['wie heißt denn der bereich denn nun?', '0'],
#  ['wie lächerlich ist das denn?', '0'],
#  ['wie groß bist du?', '0'],
#  ['wie oft macht man das in der regel?', '0'],
#  ['was hältst du davon?', '0'],
#  ['was ist rot und schlecht für die zähne?', '0'],
#  ['finden sie?', '1'],
#  ['kann mir jemand das bein brechen?', '1'],
#  ['wo befindet sich eigentlich gerade der regen?', '0'],
#  ['habt ihr auch probleme mit der app?', '1'],
#  ['könnt ihr mein notizbuch für frühdienste sein?', '1'],
#  ['hast du auch manchmal auch das gefühl,\ndass du eigentlich nirgendwo ankommst,\negal, wie weit du läufst?',
#   '1'],
#  ['was ist los?', '0'],
#  ['würdet ihr es eventuell teilen?', '1'],
#  ['ein bisschen gänsehaut zur abkühlung?', '1'],
#  ['für wen seid ihr?', '0'],
#  ['das hat überregionale relevanz?', '1'],
#  ['heute schon klamotten gezählt?', '1'],
#  ['alles gut bei dir?', '1'],
#  ['tun sich dann neue und tiefere abgründe auf?', '1'],
#  ['wen interessiert das noch im mai +number+?', '0'],
#  ['hat jemand urlaub und möchte tauschen ', '1'],
#  ['soll ich dir nen euro leihen?', '1'],
#  ['darf ich kurz eingreifen?', '1'],
#  ['was soll das?', '0'],
#  ['ich mag dich ,magst du mich?', '1'],
#  ['ist autos klauen dann also sozial?', '1'],
#  ['warum ist es so kultig?', '0'],
#  ['wäre es nicht leichter, gleich zu berichten?', '1'],
#  ['wie ist die stimmung drei jahre danach?', '0'],
#  ['was sagst du dazu?', '0'],
#  ['will jemand schreiben?', '1'],
#  ['was ist liebe überhaupt?', '0'],
#  ['läuft jetzt eigentlich jeder +number++ kilometer durch die berge?', '1'],
#  ['ein indiz für was?', '0'],
#  ['kann künstliche intelligenz einen menschlichen text angemessen bewerten?',
#   '1'],
#  ['möchtest du beim gewinnspiel mitmachen und mich unterstützen?', '1'],
#  ['gehst du bitte auch mal auf den inhalt ein?', '1'],
#  ['wie hieß es früher bei euch noch?', '0'],
#  ['wo genau findet man euch?', '0'],
#  ['sind sie sich bewusst darüber, wie viele es sind?', '1'],
#  ['hab ich da shaun das schaf gehört?', '1'],
#  ['möchte mal eine von euch versuchen mir zu folgen?', '1'],
#  ['sagen sie das beim breitscheidplatz auch?', '1'],
#  ['möchtest du müsli?', '1'],
#  ['was glaubt die polizei durch überprüfung der presseausweise zu gewinnen?',
#   '0'],
#  ['was bist denn du für einer?', '0'],
#  ['taucht sogar leandro dort auf?', '1'],
#  ['ob wir das heute nacht noch hinkriegen?', '1'],
#  ['wie genial wäre das eigentlich?', '0'],
#  ['wie jetzt?', '0'],
#  ["seit wann gibt's denn pauschaldienstreisen mit all-inclusive?", '0'],
#  ['batterien rausnehmen?', '1'],
#  ['weißt du aber, was der gemacht hat?', '1'],
#  ['wessen werte sinken in bayern?', '0'],
#  ['was ist mit den aaron?', '0'],
#  ['wo und wieso hast du einen neuen account?', '0'],
#  ['wie kommst du denn darauf jetzt?', '0'],
#  ['noch kühler?', '1'],
#  ['was scheitert eigentlich nicht in berlin?', '0'],
#  ['aber woher sollen sie das auch wissen?', '0'],
#  ['hast du deine katze mitgenommen?', '1'],
#  ["wer hat's gesagt?", '0'],
#  ['hast du hier schon geschaut?', '1'],
#  ['und, wie gefällt dir die neue photovoltaikanlage?', '0'],
#  ['wer hat zeit und lust ', '0'],
#  ['kann ich das rezept haben?', '1'],
#  ['was geht den bei euch ab?', '0'],
#  ['sagt mal, taugt fenix noch als twitter-app?', '1'],
#  ['hab ich da pommes gesehen?', '1'],
#  ['wie kann man denn bitte gefühlt täglich immer dümmeren quatsch von sich geben?',
#   '0'],
#  ['was sind die letzten worte eines frosches?', '0'],
#  ['hat es geklappt?', '1'],
#  ['was ist denn im dritten fall scheitern?', '0'],
#  ['was genau erwartest du vom staat?', '0'],
#  ['bist du ab und an noch dort?', '1'],
#  ['wohin geht es denn wann weiter?', '0'],
#  ['reitest du noch viel?', '1'],
#  ['waren ihre ferien ein flop?', '1'],
#  ['worauf habe ich mich nur eingelassen?', '0'],
#  ['kennst du schon meinen podcast?', '1'],
#  ['warum habe ich immer noch ein crush?', '0'],
#  ['blockst du ihn?', '1'],
#  ['waren sie noch nie beim wiener opernball?', '1'],
#  ['heißt dort eigentlich jeder rainer?', '1'],
#  ['warum hat spikelee ein hashtag mit bild?', '0'],
#  ['was willst du denn in essen?', '0'],
#  ['weil ich rund, faul und verfressen bin?', '1'],
#  ['womit betrinken sich mücken?', '0'],
#  ['wann fährst du denn zurück?', '0'],
#  ['hast du die schon live gesehen?', '1'],
#  ['sie wollen also heimatlos sein?', '1'],
#  ['seid ihr zusammen?', '1'],
#  ['was nutzt du denn für einen router?', '0'],
#  ['wer ist user?', '0'],
#  ['was reden wir denn schön?', '0'],
#  ["geht's noch?", '1'],
#  ['was umschreibe ich denn?', '0'],
#  ['glaubst du, dass männer multitaskingfähig sind?', '1'],
#  ['warum macht ihr das eigentlich, ihr lieben taxilenkerinnen?', '0'],
#  ['woran ich auch merke, dass sommerferien sind?', '0'],
#  ['jemand lust auf ts?', '1'],
#  ['oh kann es sein das ich diese unterhaltung zufällig kenne?', '1'],
#  ['leute finden meine usernames tatsächlich gut?', '1'],
#  ['was sind ihre stärken?', '0'],
#  ['muss die einem ständig das fernsehvergnügen versauen?', '1'],
#  ['passen die schuhe, sehen die gut aus und (wichtig) gefallen sie dir?', '1'],
#  ['den apfelkuchen oder den mann?', '0'],
#  ['was hat der jetzt damit zu tun?', '0'],
#  ['trump beschwert sich, dass +number+ % der berichterstattung über ihn negativ ist?',
#   '1'],
#  ['wie viel geld lässt der deutsche staat in rauch aufgehen?', '0'],
#  ['was habt ihr denn für den slogan gezahlt?', '0'],
#  ['worauf habe ich mich nur eingelassen?', '0'],
#  ['wo ist denn die?', '0'],
#  ['woher hast du das?', '0'],
#  ['kennt man oder?', '1'],
#  ['darf kiwi eigentlich zu dir ins bett zum kuscheln?', '1'],
#  ['welche sind die gesündesten tiere?', '0'],
#  ['was rauchst du?', '0'],
#  ['könnt ihr mir da helfen?', '1'],
#  ['wer fällt mir denn da ein, der da ganz vehement dagegen war?', '0'],
#  ['was denn?', '0'],
#  ['ist das irgendeine horrorgestalt aus maislabyrinthen, die mir noch unbekannt ist?',
#   '1'],
#  ['können wir den tweet mal bitte alle teilen?', '1'],
#  ['finanzielle unterstützung für die türkei?', '1'],
#  ['was denn sonst?', '0'],
#  ['wie lange wird es dauern, bis bei uns so etwas auch diskutiert wird?', '0'],
#  ['wo kommt denn die zahl her?', '0'],
#  ['hast du dir schon eine kabine ausgesucht?', '1'],
#  ['wie gehts euch so?', '0'],
#  ['darf ich fragen, wie zur hölle du das immer schaffst?', '1'],
#  ['hatten wir heute schon was mit schaukeln und bier?', '1'],
#  ['wie sieht es da drin aus?', '0'],
#  ['kommst du noch mit hoch?', '1'],
#  ['kann ich dich dann endlich berühren?', '1'],
#  ['hatten wir schon sommergrippe, oder darf ich dieses jahr als erstes?', '0'],
#  ['lässt sich das belegen?', '1'],
#  ['wie hieß die serie noch mal?', '0'],
#  ['wusstet ihr schon, dass gibraltar der aquarius die zulassung entzogen hat?',
#   '1'],
#  ['na was ist hier denn los?', '0'],
#  ['versteh ich das richtig?', '1'],
#  ['hat sich schon jemand den account gesichert?', '1'],
#  ['wen von den drei leuten, die du ansprichst, meinst du?', '0'],
#  ['wäre es möglich die rezeptur des lockmittels zu erfahren?', '1'],
#  ['glaubt eigentlich tatsächlich irgendwer, dass das echt ist?', '1'],
#  ['ist heute tag der grauen haken in whatsapp?', '1'],
#  ['und was soll das bringen?', '0'],
#  ['weshalb?', '0'],
#  ['warum?', '0'],
#  ['kann der tag weg oder essen sie den noch auf?', '0'],
#  ['hast du morgen schule?', '1'],
#  ['rufst du dann auch stimmung!?', '1'],
#  ['was deckt sich mit der realität?', '0'],
#  ['würdest du das dann wirklich tun?', '1'],
#  ['menschenverbot im restaurant?', '1'],
#  ['wer fabriziert so einen mist?', '0'],
#  ['meinst du mich?', '1'],
#  ['und wie genau sollen menschen ohne waffen ihre freiheit bewahren?', '0'],
#  ['soll ich mit kommen und in der nähe bleiben?', '1'],
#  ['und wieso eigentlich?', '0'],
#  ['sonst nix besseres zu tun?', '1'],
#  ['führerschein machen?', '1'],
#  ['hat das jemand behauptet?', '1'],
#  ['kapern sind voll eklig, warum geben leute geld dafür aus?', '0'],
#  ['was macht ihr so schönes?', '0'],
#  ['wer von uns beiden hat denn hier ein auto?', '0'],
#  ['kommst doch aus marl oder?', '1'],
#  ['was denn sonst?', '0'],
#  ['einverstanden?', '1'],
#  ['schatz, norbert ist auch dabei, freust du dich?', '1'],
#  ['auf welche aussage beziehen sie sich?', '0'],
#  ['soll deutschland ganz europa alimentieren?', '1'],
#  ['was gibts da zu schmunzeln?', '0'],
#  ['warum bin ich kein muttersprachler?', '0'],
#  ['hab ich schonmal erwähnt dass ich gerne einen freund hätte?', '1'],
#  ['darf ich dem discord beitreten?', '1'],
#  ['ist das rom?', '1'],
#  ['und was haben einzelne zitat mit der parteiausrichtung zu tun?', '0'],
#  ['fällt ihnen nichts auf?', '1'],
#  ['ist das nicht gar zu billig?', '1'],
#  ['waren die grünen nicht mal ursprünglich fürs tierwohl?', '1'],
#  ['ist das euer ernst?', '1'],
#  ['wisst ihr, wie sehr ich trüffel mag?', '1'],
#  ['welche unterschiede/konflikte seht ihr?', '0'],
#  ['es gab ein update?', '1'],
#  ['kann mir bitte wer sushi bringen?', '1'],
#  ['sollte es eine herausforderung sein?', '1'],
#  ['was willst du später mal beruflich machen?', '0'],
#  ['sollen wir jetzt waffen nach syrien liefern?', '1'],
#  ['es gibt sushi?', '1'],
#  ['findet es niemand bedenklich, dass heisenberg in dem witz angehalten wird, aber schrödinger antwortet?',
#   '1'],
#  ['warum hast du mir das so lange vorenthalten?', '0'],
#  ['was soll das denn heißen?', '0'],
#  ['schaff du dir etwas niveau und intellekt an und dann sprechen wir uns wieder, deal?',
#   '1'],
#  ['wo wurden deswegen mindestbeiträge eingeführt?', '0'],
#  ['seit wann hat die denn ahnung von sport?', '0'],
#  ['habt ihr mich vermisst?', '1'],
#  ['noch jemand aus leipzig?', '1'],
#  ['was ist deine größte angst?', '0'],
#  ['was bedeutet intelligente automatisierung für ihre belegschaft?', '0'],
#  ['ist die nicht mehr für motorradfahrer?', '1'],
#  ["gab's nicht auch mal auch mal künstler die nen typen umgebracht haben und sagten es sei aktionskunst?",
#   '1'],
#  ['wohin führt der weg von sebastian rudy?', '0'],
#  ['werden sie es eventuell noch rezensieren?', '1'],
#  ['wo denn?', '0'],
#  ['wollen sie ihren sohn wirklich sam nennen, frau sung?', '1'],
#  ['was sind das für vögel?', '0'],
#  ['kann es sein, dass sie ihre augen doch sehr von ihrem unmittelbaren umfeld abwenden?',
#   '1'],
#  ['wo sind all die aliens?', '0'],
#  ['wieso künstliche intelligenz?', '0'],
#  ['wurde es schon aufgelöst?', '1'],
#  ['aber schon fortnite gespielt, oder?', '1'],
#  ['auf welcher rechtsgrundlage?', '0'],
#  ['hast du denn schon hier geschaut?', '1'],
#  ['wer ist denn so in köln?', '0'],
#  ['gut, wo sitzt du?', '0'],
#  ['wie süß ist denn bitte dein patronus?', '0'],
#  ['wer ist heute alles schwimmbad?', '0'],
#  ['ist das jetzt schon deiner?', '1'],
#  ['warum kracht es eigentlich immer auf höhe pforzheim?', '0'],
#  ['trifft man dich in halle +number+ an?', '1'],
#  ['ist das normal das da so wenig drauf ist?', '1'],
#  ['was wissen sie noch von den geschehnissen der letzten woche?', '0'],
#  ['kann man noch vorbeikommen?', '1'],
#  ['wer kennt den konto-betrüger vom hardtberg?', '0'],
#  ['was soll das denn?', '0'],
#  ['will ich dich denn wirklich sehen?', '1'],
#  ['was hast du erwartet?', '0'],
#  ['kommt der neue patch mit einem praktischen item?', '1'],
#  ['warum ich den sommer liebe?', '0'],
#  ['sind wir zum verzicht bereit?', '1'],
#  ['was hast du erwartet?', '0'],
#  ['was haltet ihr von der idee in co+number+ kompensation von flügen zu investieren?',
#   '0'],
#  ['wer hatte den scheiß behauptet?', '0'],
#  ['wie hieß der kleine mann?', '0'],
#  ['wie sieht es aktuell aus?', '0'],
#  ['wurde bereits eine störung gemeldet?', '1'],
#  ['und was wäre wenn es ein spiegel journalist ist?', '0'],
#  ['bruder gibt es neue news wegen karrierenmodus?', '1'],
#  ['mehr lohn?', '1'],
#  ['kann man auch gewinnen, wenn man gerade nicht vor ort ist?', '1'],
#  ['naja ob bayrisch schwaben noch bayern ist?', '1'],
#  ['was wurde eigentlich aus serienweltde?', '0'],
#  ['sollte ich vielleicht mal weiterarbeiten?', '1'],
#  ['wie verzweifelt die ist?', '0'],
#  ['warum finde ich das so süß gerade?', '0'],
#  ['willst du noch mit hochkommen, mein paninialbum angucken?', '1'],
#  ['können patienten direkt aus der intensivstation nach hause entlassen werden?',
#   '1'],
#  ['wieso verbreitest du jetzt falsche infos?', '0'],
#  ['schaust du noch?', '1'],
#  ['wie erreicht das foto eigentlich ausgerechnet die pnn?', '0'],
#  ['ist das gerecht?', '1'],
#  ['wie ist der anstehsimulator +number+ in köln so?', '0'],
#  ['schläfst du da jetzt?', '1'],
#  ['bringst mir was mit?', '1'],
#  ['hallo, kann man das bei ihnen auch mal?', '1'],
#  ['kann man als hähnchenwagenmann homeoffice machen?', '1'],
#  ['hast du zufällig die norma online webseite offen gehabt?', '1'],
#  ['wie steht es um gottes gerechtigkeit?', '0'],
#  ['und nach welchem studium gibt es die höchste einstiegszufriedenheit?', '0'],
#  ['wie cool ist das denn?', '0'],
#  ['ist dies eigentlich, eine für spd-wahlkämpfe, optimierte typografie?', '1'],
#  ['wer soll das glauben?', '0'],
#  ['ich sehe heute abend the black dahlia murder im logo, wer noch?', '0'],
#  ['werde ich wohnen?', '1'],
#  ['wo ist deren tweet denn so schnell hin verschwunden?', '0'],
#  ['haben die kalte füße bekommen?', '1'],
#  ['hast du schon call of cthulhu gesehen?', '1'],
#  ['ist heute auch bei dir ein tag der tage?', '1'],
#  ['was macht ihr so?', '0'],
#  ['wo sind die eltern unter euch?', '0'],
#  ['ein jahr?', '1'],
#  ['in einem sportverein?', '1'],
#  ['wann bist du in köln?', '0'],
#  ['was ist wenn ich nicht franz heiße, nicht +number+ bin und nicht daniels bruder?',
#   '0'],
#  ['echt jetzt?', '1'],
#  ['die sind etwas später, was?', '1'],
#  ['könnte world war +number+ den giganten battlefield vom thron kicken?', '1'],
#  ['echte kameradschaft statt singleplayer-modus?', '1'],
#  ['das wahre problem ist...?', '0'],
#  ['thierry henry neuer trainer von bordeaux?', '1'],
#  ['willst du dich individuell im basketball weiterentwickeln?', '1'],
#  ['was soll ich sagen?', '0'],
#  ['wie kann man unabhängiger wkö-präsident sein und gleichzeitig övp wirtschaftsbund präsident?',
#   '0'],
#  ['was war es?', '0'],
#  ['wir sind schon da, aber wo bist du?', '0'],
#  ['wieso wundert es mich nicht?', '0'],
#  ['warum muss er dies tun?', '0'],
#  ['wofür werden sie eigentlich bezahlt?', '0'],
#  ['wie geht es weiter mit den transatlantischen beziehungen?', '0'],
#  ['ich hoffe ihr seid inzwischen durch?', '1'],
#  ['was meinst du gehst du drauf ein?', '1'],
#  ['was denkt ihr?', '0'],
#  ['geklaute fahrräder finden den weg zurück?', '1'],
#  ['läuten die entwicklungen in den fällen cohen und manafort das ende der ära ein?',
#   '1'],
#  ["was gibt's bei euch so neues?", '0'],
#  ['höhere preise für alle?', '1'],
#  ['wie viel ist eine seele eigentlich wert?', '0'],
#  ['startelf oder bank?', '0'],
#  ['was ist normal?', '0'],
#  ['wie alt ist die jetzt eigentlich?', '0'],
#  ['haben sie fünf minuten zeit?', '1'],
#  ['könnte es sein, dass die bundesagentur für arbeit ganz einfach lügt?', '1'],
#  ['wer ist denn alles in eurem legal panel?', '0'],
#  ['hey crew, was empfehlt ihr in sachen kamera- und videoschnitt-apps auf android?',
#   '0'],
#  ['gibt es etwas was dieser feststellung widerspricht?', '1'],
#  ['wundert das noch einen?', '1'],
#  ['wo bleibt die kontrolle?', '0'],
#  ['seh ich aus wie ein auto?', '1'],
#  ['werden ihre heizkosten korrekt berechnet?', '1'],
#  ['wo ist der verfassungsschutz?', '0'],
#  ['ist das dein sohn?', '1'],
#  ['können sie sich jetzt bitte selbst um ihre nachhilfe kümmern?', '1'],
#  ['wer ist auf der messe und hat denn noch lust was zu spielen?', '0'],
#  ['welche glastür?', '0'],
#  ['kannst du mir dazu bitte kurz den vertrag rausgoogeln?', '1'],
#  ['dafür brauchen die eine studie?', '1'],
#  ['wieso ist es überhaupt erlaubt so tiere zu halten?', '0'],
#  ['taugt das neue addon was?', '1'],
#  ['wer hat genau welchen schaden?', '0'],
#  ['ist jetzt stillstand?', '1'],
#  ['wird es nun eng für trump?', '1'],
#  ['ach und das haben sie geleugnet?', '1'],
#  ['wie weit ist es denn bzw. wie lange bist du unterwegs?', '0'],
#  ['was versteht jemand wie du schon vom fußball?', '0'],
#  ['wenn man sich selbst vorschlägt ist das dann unsympathisch?', '1'],
#  ['stellt sich bei dir die wahl überhaupt?', '1'],
#  ["gibt's nen kicker und kaffeeflatrate?", '1'],
#  ['hi, kannst du mir bitte die sendungsnummer per dn schicken?', '1'],
#  ['oh wow, wie kann man nur so schön aussehen?', '0'],
#  ['was muss man tun, damit ein amazon prime paket ankommt?', '0'],
#  ['ist das jetzt schon deiner?', '1'],
#  ['hat jemand gute mods für sims?', '1'],
#  ['bei welchen airlines gibt es noch kostenloses essen?', '0'],
#  ['in welchem hotel geht das am besten?', '0'],
#  ['warum hast du gestern den stream so plötzlich ausgeschaltet?', '0'],
#  ['geht die tür zu dir oder zu ihr auf?', '0'],
#  ['finden sie das irgendwie lustig?', '1'],
#  ['hätte die sz nicht berichten sollen?', '1'],
#  ['subventionen für seine verwandtschaft?', '1'],
#  ['abreißen oder stützen?', '0'],
#  ['wann kriegt ihr die wartezeiten generell endlich in den griff?', '0'],
#  ['ist das immer noch gültig?', '1'],
#  ['wer muss streichen?', '0'],
#  ['hab ich irgendwelchen blödsinn gemacht?', '1'],
#  ['gehts noch?', '1'],
#  ['echt jetzt?', '1'],
#  ['bei schulbüchern geht ihr durch die decke?', '1'],
#  ['wann bist du öfter auf twitter aktiv?', '1'],
#  ['was unterscheidet aachen von anderen städten?', '0'],
#  ['was macht die stadt besonders?', '0'],
#  ['weiß noch jemand was ich damit vor hatte?', '1'],
#  ['wo stehen sie in der digitalisierung und was sind die nächsten schritte?',
#   '0'],
#  ['darf ich das reposten mit quelle zu dir?', '1'],
#  ['wieder wegen der hitze?', '1'],
#  ['wo die sind?', '0'],
#  ['du guckst auch den glücksdetektiv?', '1'],
#  ['gab es schon gespräche zur soforthilfe für solariumbetreiber?', '1'],
#  ['abkühlung gefällig?', '1'],
#  ['was wäre, wenn deine spülmaschine dir sagt, wann sie neue tabs braucht?',
#   '0'],
#  ['wer hat denn jemals behauptet hübsche frauen kein instrument spielen können?',
#   '0'],
#  ['was soll sich geändert haben?', '0'],
#  ['wie kann ein progressives europa aussehen?', '0'],
#  ['was brauchen gute fotos?', '0'],
#  ['und was hat das eine mit dem anderen zu tun?', '0'],
#  ['was für ein ruf hat denn die tagesschau?', '0'],
#  ['ist ihr job eher langweilige routine oder macht er sie glücklich?', '0'],
#  ['seid ihr am start?', '1'],
#  ['wozu braucht europa noch grenzen???', '0'],
#  ['wie alt schätzt du ihn?', '0'],
#  ['was lernen wir daraus?', '0'],
#  ['sagt wer?', '0'],
#  ['mehr lohn?', '1'],
#  ['würdest du das mit mir machen?', '1'],
#  ['gibt es einen unterschied?', '1'],
#  ['ist eine online feedback community der mercedes unter den marktforschungstools?',
#   '1'],
#  ['hey du, kennst du die qualität deiner webanalyse-daten?', '1'],
#  ['entscheidest du mit guten daten?', '1'],
#  ['wie kannst du das überprüfen?', '0'],
#  ['und wer regiert uns heute nochmal?', '0'],
#  ['wer schleppt denn so einen stein über die ganze gamescom?', '0'],
#  ['und in welchem rahmen soll das jetzt in die diskussion über lehrkräfte eingebaut werden?',
#   '0'],
#  ['was ihr habt den tweet gelesen und keine million euro dafür bezahlt?', '1'],
#  ['für wenn lebst du denn wenn nicht für dich?', '0'],
#  ['und wieso?', '0'],
#  ['selbstironie?', '1'],
#  ['ganz ohne augenbrauen und lachen?', '1'],
#  ['hast du auch so einen verrückten zu hause ', '1'],
#  ['könntest du mir bitte deine alte brille zuschicken?', '1'],
#  ['für twitter muss man also volljährig sein?', '1'],
#  ['warum muss es genau dann wieder warm werden, wenn ich wieder mit dem lernen anfange?',
#   '0'],
#  ['war ich da dabei?', '1'],
#  ['sein wann gehören wunder in den ressortzuschnitt des wirtschaftsministeriums?',
#   '0'],
#  ['so langsam?', '1'],
#  ['beschäftigt ihr österreicher?', '1'],
#  ['warum ist dieser mann kein held?', '0'],
#  ['was hat der arme kerl denn?', '0'],
#  ['texterin gesucht?', '1'],
#  ['und was ist mit bing?', '0'],
#  ['meinen sie, ich benötige gedächtnistraining?', '1'],
#  ['haben sie sich vertippt?', '1'],
#  ['wollten sie moos schreiben?', '1'],
#  ['ich dachte du bist jeden tag auf der gamescom?', '1'],
#  ['haben sie diesen mann schon einmal gesehen?', '1'],
#  ['welchen teil des grundgesetzes setzen wir jetzt außer kraft?', '0'],
#  ['welches ist das beste template für binäre optionen und cfd?', '0'],
#  ['ist das ein fake?', '1'],
#  ['wie um alles in der welt?', '0'],
#  ['was taugen die +number+-euro-trachten?', '0'],
#  ['wo ist das problem?', '0'],
#  ['darf ich?', '1'],
#  ['findest du gut was?', '1'],
#  ['habt ihr schon bei unserer instachallenge mitgemacht?', '1'],
#  ['ist die mannschaft überhaupt bundesligatauglich?', '1'],
#  ['muss der trainer gehen?', '1'],
#  ['hast du geprüft, ob das kosteneffizient ist?', '1'],
#  ['hast du zufällig noch seinen siegerkader als bild oder so gespeichert?',
#   '1'],
#  ['wie denn sonst?', '0'],
#  ['was halten sie davon?', '0'],
#  ['was meinst du damit?', '0'],
#  ['wo ist thomas gottschalk?', '0'],
#  ['aber wie hoch sind die anschaffungs- und betriebskosten?', '0'],
#  ['hast du einen link hierfür?', '1'],
#  ['kann man die plakate irgendwo bekommen?', '1'],
#  ['sind die aus dem zoo ausgebrochen?', '1'],
#  ['eine andere möglichkeit von zug zur anreise gibt es nicht?', '0'],
#  ['welche folge war das?', '0'],
#  ['mindert dieser ausblick eigentlich den immobilienwert?', '1'],
#  ['du wohnst in ffm und regst dich über falschparker/-steher auf?', '1'],
#  ['bleiben wir in kontakt?', '1'],
#  ['wundert es jemanden?', '1'],
#  ['wer hat uns verraten?', '0'],
#  ['seid ihr am start?', '1'],
#  ['wer war nochmal seit ewigkeiten in bayern an der macht?', '0'],
#  ['und das hat dann warum bisher nie geklappt?', '0'],
#  ['wie kommt man damit denn aus?', '0'],
#  ['sind das rohe eier?', '1'],
#  ['wer bringt mir ne axt?', '0'],
#  ['brauchen wir dafür sticker?', '1'],
#  ['wo denn?', '0'],
#  ['wolltest du nicht aufhören?', '1'],
#  ['funktioniert alles?', '1'],
#  ['muss ich jemand bestimmtes ansprechen?', '1'],
#  ['dann darf mir aber der unterhalt auch nicht abgezogen werden?', '1'],
#  ['zählt ein vakuum auch als inhalt?', '1'],
#  ['bekommt man jetzt weder auf die eingereichte beschwerde noch hier eine antwort?',
#   '1'],
#  ['und was machst du wenn dich mal die wildecker herzbuben besuchen wollen?',
#   '0'],
#  ['wär vielleicht ein bisschen groß ', '1'],
#  ['sag mir, was ist das zwischen uns?', '0'],
#  ['was sollte der hier?', '0'],
#  ['welche spiele hast du auf deinem handy installiert?', '0'],
#  ['und wie geht das?', '0'],
#  ['machst du noch videos?', '1'],
#  ['wie kannst du nur mit dieser schrift leben?', '0'],
#  ['wie immer?', '1'],
#  ['geht es um +number+ uhr los oder verkündetet ihr dann wo es ist?', '0'],
#  ['warum heisst es eigentlich wartezimmer ', '0'],
#  ['wie spreche ich z.b. einen wunschkontakt in business-netzwerken an?', '0'],
#  ['warum sollte nintendo den preis senken solange die verkäufe noch stark genug sind?',
#   '0'],
#  ['sicher das er das buch nicht noch auf den letzten drücker zuende schreibt?',
#   '1'],
#  ["geht's nach köln?", '1'],
#  ['kam der auftrag für den hack aus dem kreml oder aus dem weißen haus?', '0'],
#  ['war das nicht immer der vorwurf gegen gamer?', '1'],
#  ['gibt etwas was dieser feststellung widerspricht?', '1'],
#  ['hast du es schon signiert?', '1'],
#  ['was ist denn hier los?', '0'],
#  ['deiner nun auch?', '1'],
#  ["sowas gibt's?", '1'],
#  ['sehen sich doch ähnlich oder?', '1'],
#  ['wo ist das problem?', '0'],
#  ['passt der wagen in den aufzug?', '1'],
#  ['der weg zum glück?', '1'],
#  ['ok wartest du noch kurz?', '1'],
#  ['ist das noch eine bundeswehr?', '1'],
#  ['ihre vorschläge?', '0'],
#  ['hätte sie es ignorieren sollen?', '1'],
#  ['hätte sie die augen vor den unmenschlichen zuständen verschließen sollen?',
#   '1'],
#  ['was halten sie davon?', '0'],
#  ["allerdings - was passiert, wenn das alle wirte so machen und es fast nur noch solche 'angebote' gibt?",
#   '0'],
#  ['sie kalkulieren mit einem job im finanz- und rechnungswesen?', '1'],
#  ['du willst einen job, in dem du viel bewegen kannst?', '1'],
#  ['wie nimmt mein baby die medizin?', '0'],
#  ['weiß jemand, wie es mit diesen angehefteten tweets funktioniert?', '1'],
#  ['muss man dafür zahlen?', '1'],
#  ['erinnerst du dich noch, wann du dich für twitter registriert hast?', '1'],
#  ['was sind die ursachen dieser gewalt?', '0'],
#  ['wie können sie bekämpft werden?', '0'],
#  ['steht megatron mit auf der liste?', '1'],
#  ['warum wird der mann jetzt an die öffentlichkeit gezerrt?', '0'],
#  ['wen interessiert das schon?', '0'],
#  ['ist made in germany immer noch ein gütesiegel?', '1'],
#  ['ich hoffe, du kannst ihn genießen?', '1'],
#  ['habt ihr schon neue informationen bezüglich der übertragungen?', '1'],
#  ['oma, kann ich zwei kugeln eis haben?', '1'],
#  ['kann das denn so schwierig sein?', '1'],
#  ['schon gelesen?', '1'],
#  ['ich will ihm helfen, aber wie?', '0'],
#  ['wisst ihr da mehr?', '1'],
#  ['warum sollte das ein skandal sein?', '0'],
#  ['darf ich das foto klauen?', '1'],
#  ['warum sieht auf diesem foto alles so aus, als sei es +number+?', '0'],
#  ['wer kennt das nicht?', '0'],
#  ['fallen jetzt auch die anderen?', '1'],
#  ['was willst du mir jetzt damit sagen?', '0'],
#  ['mama, was ist eine goldwaage?', '0'],
#  ['ist künstliche intelligenz der zukunftsträger der logistik?', '1'],
#  ['welchen mehrwert hat user generated content für museen und kulturinstitutionen?',
#   '0'],
#  ['wer kann da widersprechen?', '0'],
#  ['freut ihr euch auch schon so sehr?', '1'],
#  ['was ist denn heute morgen los?', '0'],
#  ['was ist verkehrt an dem kundenbild?', '0'],
#  ['weißt du wie das pedal funktioniert?', '1'],
#  ['sehen wir uns heute abend, +number+ uhr?', '1'],
#  ['wer mag noch mitmachen?', '0'],
#  ['ist noch irgendwo kaffee in der kanne?', '1'],
#  ['ab wann sind historische vergleiche erlaubt?', '0'],
#  ['und wieso gelten für dieses kabel die längenbeschränkungen nicht?', '0'],
#  ['echt jetzt?', '1'],
#  ['merken sie den unterschied?', '1'],
#  ['wer feiert mit uns?', '0'],
#  ['um +number+ ist regulär einlass oder?', '1'],
#  ['woher kommt eigentlich diese zunahme?', '0'],
#  ['was glaubt ihr eigentlich, wofür öffentliche räume so sind?', '0'],
#  ['können wir nicht von etwas anderem sprechen?', '1'],
#  ['ob es den wohl noch gibt?', '1'],
#  ['stimmt oder stimmt nicht?', '0'],
#  ['hattest du dir eigentlich den wischsauger gekauft?', '1'],
#  ['schon eine wattwanderung gemacht?', '1'],
#  ['bist du in der nähe von st. peterording?', '1'],
#  ['wie findet man die richtigen?', '0'],
#  ['warum wollen sie für uns arbeiten?', '0'],
#  ['wie wäre es denn mal mit einer freigrenze bei der grunderwerbsteuer?', '0'],
#  ['könnt ihr schon schlafen?', '1'],
#  ['hast du schon unsere neue, wasserabweisende fieldjacke für herren entdeckt?',
#   '1'],
#  ['schon gewusst?', '1'],
#  ['gibst du freiwillig ab oder bist du verpflichtet?', '0'],
#  ['dürfen arbeitnehmer während der arbeitszeit einfach zum arzt gehen?', '1'],
#  ['was geschieht bei euch in der region, wovon wir nichts mitbekommen?', '0'],
#  ['wie sieht es den optisch aus?', '0'],
#  ['noch besser als auf der wiiu?', '1'],
#  ['geht es euch auch immer so, wenn ihr in ein büchergeschäft geht?', '1'],
#  ['hat das da nicht tradition?', '1'],
#  ['wurden alle verbeamtet?', '1'],
#  ['könnten wir jetzt bitte den sommer noch mal von vorne starten?', '1'],
#  ['müsste man als fahrradfahrer dann nicht auf der straße fahren?', '1'],
#  ['wo sind die kinder?', '0'],
#  ['wie funktioniert der betrieb eines privatpools?', '0'],
#  ['wie lange kann die aktuelle hochphase der bullen an der börse eigentlich noch anhalten?',
#   '0'],
#  ['hast du am gewinnspiel teilgenommen?', '1'],
#  ['sie wollen eine unserer schalungslösungen unverbindlich testen?', '1'],
#  ['was ist der grund dafür, dass ich jemanden vertraue?', '0'],
#  ['und dann hast du sicher schlechte laune?', '1'],
#  ['wer hilft kranken oder älteren leute schwere sachen treppen hochzuwuchten?',
#   '0'],
#  ['wer kann mir helfen?', '0'],
#  ['lügen die medien?', '1'],
#  ['wann seid ihr eigentlich da?', '0'],
#  ['wer ist archie?', '0'],
#  ['oh, fährst du durch kutenhausen?', '1'],
#  ['warum aber keine expertinnen der arbeit im digitalrat?', '0'],
#  ['hat william sich scheiden lassen?', '1'],
#  ['würde darunter nicht auch der videofilm einer handykamera fallen?', '1'],
#  ['hast du urteile/aktenzeichen?', '1'],
#  ['ab wann beginnt man zu fantasieren?', '0'],
#  ['in welcher welt soll das klappen?', '0'],
#  ['wann macht der pausenclown eigentlich pause?', '0'],
#  ['wieviel chinesen gibt es?', '0'],
#  ['hast du einen telefonjoker bemüht?', '1'],
#  ['wenn man zuerst pasta und dann antipasti isst, hat man dann überhaupt was gegessen?',
#   '1'],
#  ['warum schreibt man fast alles doppelt?', '0'],
#  ['wo muss man eigentlich hinkommen, um dich morgen zu sehen?', '0'],
#  ['ja und was beweist das jetzt?', '0'],
#  ['wann geht es endlich los?', '0'],
#  ['wieviel personen haben bei der umfrage teilgenommen?', '0'],
#  ['welche konsequenzen zieht man denn daraus?', '0'],
#  ['was lernen wir aus der heutigen hitzewelle?', '0'],
#  ['können wir mal ne runde zusammen spielen?', '1'],
#  ['wie sagte vorhin jenand?', '0'],
#  ['wieso ist heute schon donnerstag?', '0'],
#  ['würde ein langer rock denn gehen?', '1'],
#  ['haben sie schon das gehört?', '1'],
#  ['wie lange kennt ihr euch schon?', '0'],
#  ['wie kann man nur so sein?', '0'],
#  ['ist das gut?', '1'],
#  ['ist made in germany immer noch ein gütesiegel?', '1'],
#  ['haben sich die ärzte jetzt abgesprochen das sie einfach nicht mehr ans telefon gehen?',
#   '1'],
#  ['warum sollte das ein skandal sein?', '0'],
#  ['gibt es dazu konkrete zahlen oder ist das nur gesülze?', '0'],
#  ['gibt es in photoshop eine möglichkeit, viele einzelbilder automatisch in einem raster anzuordnen?',
#   '1'],
#  ['wer denn sonst?', '0'],
#  ['sehen sie immer das glas halbvoll und nicht halbleer?', '1'],
#  ['wie heißt die firma, die weltweit die größte summe von firmenanleihen besitzt?',
#   '0'],
#  ['du wohnst in der nähe von korneuburg und möchtest zwichen +number+ und +number+ stunden arbeiten?',
#   '1'],
#  ['fällt euch was auf?', '1'],
#  ['war der tweet bevor oder nachdem das brot geschmiert wurde?', '0'],
#  ['sollen wir daraus ein geburtstagsgeschenk machen?', '1'],
#  ['hab ich was verpasst?', '1'],
#  ['lassen sie mich raten, heute war es auch wieder ein vorausfahrender zug?',
#   '1'],
#  ['was ist denn mit karsten los?', '0'],
#  ['was will uns der künstler mit diesem werk denn sagen?', '0'],
#  ['wo kann man den artikel lesen?', '0'],
#  ['fällt euch was auf?', '1'],
#  ['vielleicht spaß an der sache?', '1'],
#  ['welche games wollt ihr auf youtube bzw. twitch sehen?', '0'],
#  ['wäre das machbar?', '1'],
#  ['und warum werden dann windkraftanlagen in den wald gebaut?', '0'],
#  ['wisst ihr was so richtig richtig witzig ist?', '1'],
#  ['wussten sie es?', '1'],
#  ['auf basis welcher berechnung steht ihre aussage?', '0'],
#  ['was ist hier los?', '0'],
#  ["gibt's was um sonst?", '1'],
#  ['warum sind sie dann nicht hier?', '0'],
#  ['der typ ist doch dein bruder, oder?', '1'],
#  ['wollen wir für mich sammeln?', '1'],
#  ['woher ist dieser pullover?', '0'],
#  ['wer sind sie?', '0'],
#  ['wo ist der schnurrbart?', '0'],
#  ['kommt die frau wieder?', '1'],
#  ['habt ihr noch einen platz frei?', '1'],
#  ['wo kommst du denn ursprünglich her?', '0'],
#  ['was meinst wäre los, wenn ich dir das recht auf selbstbestimmung abspräche?',
#   '0'],
#  ['was wäre, wenn der rest der welt die usa mit denselben standards behandeln würde?',
#   '0'],
#  ['warum sprichst du mir ab das nicht zu verstehen?', '0'],
#  ['wie kommst du jetzt darauf?', '0'],
#  ["gibt's ne aufnahme wie er auf den bericht reagiert?", '1'],
#  ['was nutzt du denn für teamkommunikation?', '0'],
#  ['hättest du mal lust als gast in meine sendung zu kommen?', '1'],
#  ...]
